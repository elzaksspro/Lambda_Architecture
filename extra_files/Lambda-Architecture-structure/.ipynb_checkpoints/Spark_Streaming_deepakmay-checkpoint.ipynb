# %%
# import org.apache.spark.sql.cassandra._

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from Activity import Activity
from activityByProduct import activityByProduct
from pyspark.streaming.kafka import KafkaUtils
import os

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--conf spark.ui.port=4040 --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.0.0,com.datastax.spark:spark-cassandra-connector_2.11:2.0.0-M3 pyspark-shell'

# %%
conf = SparkConf() \
    .setAppName("Streaming test") \
    .setMaster("local[2]") \
    .set("spark.cassandra.connection.host", "127.0.0.1")
sc = SparkContext(conf=conf) 
sqlcontext=SQLContext(sc)

# %%
# conf.setAppName("Spark Cassandra")

# %%
# conf.set("spark.cassandra.connection.host","localhost")

# %%
# # sc = SparkContext(appName="PythonSparkStreamingKafka")
# sc = SparkContext(conf=conf)

# sc.setLogLevel("WARN")

# %%
# sqlcontext = SQLContext(sc)

# %%
# from cassandra.cluster import Cluster

# %%
# cluster = Cluster()

# %%
# session = cluster.connect('lambda')

# %%
# rows = session.execute("SELECT * FROM lambda.emp;")

# %%
# rows.column_types

# %%
ssc = StreamingContext(sc,2)

# %%
textDStream1 = KafkaUtils.createStream(ssc, 'localhost:2181', 'spark-streaming', {'data_pipeline':1})
textDStream = textDStream1.map(lambda x: x[1])

# %%
def subprocess(line):
    records = line.split("\t")
    if records[0] != "action" and len(records) == 7:
        return Activity(records[0],records[1],records[2],records[3],records[4],records[5],records[6])
    else:
        return None

# %%
def process(rdd):
    if not rdd.isEmpty():
        newRDD = rdd.map(subprocess)
    else:
        newRDD = None
    return newRDD

# %%
def process_query(rdd):
    if not rdd.isEmpty():
        newDF=rdd.map(lambda x: (x, )).toDF()
        newDF2 = newDF.select('_1.*')
        newDF2.createOrReplaceTempView("Activity")
#         toHDFS = sqlcontext.sql("select * from activity")
# #         toHDFS.write.mode("append").csv("hdfs://localhost:9000/kafka_spark",header=True)
#         toHDFS2 = toHDFS.select(['action', 'page', 'product', 'referrer', 'timestamp_hour', 'visitor'])
        visitorsByProduct = sqlcontext.sql("SELECT product, timestamp_hour, COUNT(DISTINCT visitor) as unique_visitors FROM Activity GROUP BY product, timestamp_hour")
        visitorsByProduct.show(10)
        visitorsByProduct.printSchema()
        visitorsByProduct.fillna()
        visitorsByProduct.write.format("org.apache.spark.sql.cassandra").mode('append').options(table="stream_visitors_by_product_text", keyspace="lambda").save()

# %%
newDStream = textDStream.transform(process)

# %%
newDStream.foreachRDD(process_query)

# %%
# newDStream.pprint()

# %%
ssc.start()

# %%
# ssc.stop(stopSparkContext=False,stopGraceFully=True)

# %%
# df = sqlcontext.read.csv('hdfs://localhost:9000/kafka_spark/part-00000-00535f69-81ae-4191-bda1-fbcd66209aaf-c000.csv', header=True, inferSchema=True)

# %%
# df.printSchema()
# Out:
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |
              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Sharpie,Fine Perm...| 1521807836513|              1|
# |Dove,Clean Comfor...| 1521807838433|              1|
# |Colgate,Toothbrus...| 1521807839393|              1|
# |The Learning Comp...| 1521807830273|              1|
# |Nintendo,Super Ma...| 1521807840353|              1|
# |up & up,Toothbrus...| 1521807837953|              1|
# |Gatorade,Fierce G...| 1521807836033|              1|
# |Thymes,Kimono Ros...| 1521807830753|              1|
# |   Google,Chromecast| 1521807842753|              1|
# |Blue Diamond,Almo...| 1521807828353|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |     Kraft,Cool Whip| 1521807836634|              1|
# |Clean & Clear,Ess...| 1521807830394|              1|
# |Band-Aid,Flexible...| 1521807834714|              1|
# |         OYO,Whiskey| 1521807834714|              1|
# |Glad,Odor Shield ...| 1521807839514|              1|
# |Sol Republic,JAX ...| 1521807838074|              1|
# |Arm & Hammer,Ultr...| 1521807838554|              1|
# |Glass Plus,Glass ...| 1521807832794|              1|
# |e.l.f.,Smudge Pot...| 1521807830394|              1|
# |CVS Total Home,"A...| 1521807839514|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |         OYO,Whiskey| 1521807841553|              1|
# |Clean & Clear,Acn...| 1521807833393|              1|
# |Ancient Harvest,Q...| 1521807837713|              1|
# |All,"Mighty Pacs,...| 1521807844913|              1|
# | Ralphs,Plastic Wrap| 1521807832433|              1|
# |Purell,Advanced H...| 1521807833393|              1|
# |Dave's Gourmet,Re...| 1521807840593|              1|
# |Gatorade,Frost Ri...| 1521807842993|              1|
# |Cover Girl,Flamed...| 1521807834353|              1|
# |Staples,Standard ...| 1521807843953|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Red Vines,Origina...| 1521807845993|              1|
# |Lysol,Bathroom Cl...| 1521807833513|              1|
# |Botanics,Hydratin...| 1521807833993|              1|
# |Dove,Moisturizing...| 1521807844073|              1|
# |Clover Stornetta,...| 1521807844073|              1|
# |Simple,Cleansing ...| 1521807835913|              1|
# |Trader Joe's,Curr...| 1521807841673|              1|
# |Energizer,392 Wat...| 1521807842633|              1|
# |Pond's,Dry Skin C...| 1521807839753|              1|
# |Nivea,Sensitive M...| 1521807836393|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |California Pizza ...| 1521807849466|              1|
# |CVS Total Home,"A...| 1521807841306|              1|
# |Caliber,Security ...| 1521807847066|              1|
# |Motorola,SURFboar...| 1521807842746|              1|
# |Nivea,Sensitive M...| 1521807848026|              1|
# |Banquet,Brown 'N ...| 1521807847066|              1|
# |Nintendo,Super Ma...| 1521807835066|              1|
# |Jolen,Creme Bleac...| 1521807848026|              1|
# |Clean & Clear,Ess...| 1521807836026|              1|
# |Clif Bar,Chocolat...| 1521807842746|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |     Mars,Peanut M&M| 1521807838541|              1|
# |Cover Girl,Flamed...| 1521807856301|              1|
# |Nivea,Sensitive M...| 1521807852941|              1|
# |Banquet,Brown 'N ...| 1521807846701|              1|
# |Opti-Free,Pure Mo...| 1521807846701|              2|
# |Avery,White Reinf...| 1521807854861|              1|
# |Cloud 9,Cutlery C...| 1521807851501|              2|
# |Scrub Daddy,Spong...| 1521807838061|              1|
# |David's Tea,Organ...| 1521807847181|              1|
# |Pantene,Repair & ...| 1521807854861|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |La Tourangelle,Gr...| 1521807842513|              1|
# |Tapatio,Salsa Pic...| 1521807846353|              1|
# |Kind,Thai Sweet C...| 1521807842513|              1|
# |Staples,Small Bin...| 1521807841553|              1|
# |Heinz,Distilled W...| 1521807841553|              1|
# |CVS Pharmacy,91% ...| 1521807841073|              1|
# |Clover Stornetta,...| 1521807841553|              2|
# |Kleenex,White Tis...| 1521807841553|              1|
# |Clean & Clear,Ess...| 1521807845873|              1|
# |Pond's,Cold Cream...| 1521807840593|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Banana Boat,Sport...| 1521807848861|              1|
# |Scrabble,Crosswor...| 1521807850301|              1|
# | Ralphs,Plastic Wrap| 1521807851261|              1|
# |Band-Aid,Flexible...| 1521807848861|              1|
# |Pond's,Dry Skin C...| 1521807847901|              1|
# |La Tourangelle,Gr...| 1521807845021|              1|
# |Duracell,76A Dura...| 1521807849821|              1|
# |Glass Plus,Glass ...| 1521807845021|              1|
# |L'Oreal,Out of Be...| 1521807844541|              1|
# |Vicks,DayQuil Sev...| 1521807844061|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |L'Oreal,Out of Be...| 1521807853771|              1|
# | Q-tips,Cotton Swabs| 1521807858571|              1|
# |Walgreens,Advance...| 1521807854251|              1|
# |Safeway,Whole Bla...| 1521807852811|              1|
# |Molton Brown,Re-C...| 1521807853771|              1|
# |Kleenex,White Tis...| 1521807847051|              1|
# |Pond's,Cold Cream...| 1521807844651|              1|
# |Neutrogena,Alcoho...| 1521807859051|              1|
# |Axe,Axe Anarchy f...| 1521807853291|              1|
# |   Tapatio,Hot Sauce| 1521807859051|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Jolen,Creme Bleac...| 1521807850049|              1|
# |Secret,pH Balance...| 1521807845729|              1|
# |Kettle,Classic Ba...| 1521807846689|              2|
# |Kroger,Vanilla Ex...| 1521807847169|              1|
# |Heinz,Distilled W...| 1521807846689|              2|
# |De Cecco,Penne Ri...| 1521807846689|              1|
# |Ziploc,Double Zip...| 1521807849089|              1|
# |   CVS,2-Ply Tissues| 1521807846209|              1|
# |Safeway,Whole Bla...| 1521807855809|              2|
# |Wexford,College R...| 1521807848129|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Reynolds,Parchmen...| 1521807851118|              1|
# |McCormick,Whole B...| 1521807850638|              1|
# |Pond's,Cold Cream...| 1521807855918|              1|
# |Trident,Spearmint...| 1521807854958|              1|
# |Santa Sweets,Grap...| 1521807848718|              1|
# |CVS Total Home,"A...| 1521807851598|              1|
# |      Kroger,2% Milk| 1521807849198|              1|
# |Kettle,Classic Ba...| 1521807852558|              1|
# |Sol Republic,JAX ...| 1521807854958|              1|
# |Crest,Pro-Health ...| 1521807865998|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Pond's,Dry Skin C...| 1521807858921|              1|
# |David's Tea,Birth...| 1521807849801|              1|
# |Tropicana,Orange ...| 1521807856521|              1|
# |Scott,One Ply Bat...| 1521807860841|              1|
# |  Kroger,Garlic Salt| 1521807855561|              1|
# |RadioShack,PIR Se...| 1521807855081|              1|
# |  Bolla,Pinot Grigio| 1521807857001|              1|
# |Palmolive,Origina...| 1521807849801|              1|
# |Kind,Dark Chocola...| 1521807852201|              1|
# |Avery,White Easy ...| 1521807860841|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Neutrogena,Oil-Fr...| 1521807863834|              1|
# |All,"Mighty Pacs,...| 1521807853754|              1|
# |e.l.f.,Smudge Pot...| 1521807860954|              1|
# |Aveeno,Clear Comp...| 1521807864314|              1|
# |Ralphs,Nice 'n El...| 1521807852314|              1|
# |Nivea,Original Mo...| 1521807853754|              1|
# |Avery,Permanent R...| 1521807858074|              1|
# |Tapatio,Salsa Pic...| 1521807863354|              1|
# |  Kroger,Garlic Salt| 1521807857594|              1|
# |Trader Joe's,Extr...| 1521807862394|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Banana Boat,Sport...| 1521807858191|              1|
# |Aveeno,Men's Afte...| 1521807868271|              1|
# |   Tapatio,Hot Sauce| 1521807867311|              1|
# |RadioShack,PIR Se...| 1521807854831|              1|
# |Avery,White Easy ...| 1521807856271|              1|
# |Edge,Sensitive Sk...| 1521807864911|              1|
# |Ziploc,Double Zip...| 1521807871631|              1|
# |Clover Stornetta,...| 1521807858671|              1|
# |Kind,Dark Chocola...| 1521807866831|              1|
# |Thymes,Kimono Ros...| 1521807860111|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Mars,Peanut Butte...| 1521807867433|              1|
# |Avery,White Easy ...| 1521807863113|              1|
# |Sanyo,Eneloop 4 A...| 1521807861193|              1|
# |Band-Aid,Flexible...| 1521807856393|              1|
# |Green Giant,Cut G...| 1521807857353|              1|
# |Glass Plus,Glass ...| 1521807865513|              1|
# |  Dixie,Paper Plates| 1521807865513|              1|
# |Chemin Du Soleil,...| 1521807865033|              1|
# |Reynolds,Slow Coo...| 1521807860713|              1|
# |Nintendo,Super Ma...| 1521807857353|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |   Tapatio,Hot Sauce| 1521807867545|              1|
# |Caliber,Security ...| 1521807865625|              1|
# |Jergens,Natural Glow| 1521807863225|              1|
# |Scott,One Ply Bat...| 1521807865625|              1|
# |Dove,Moisturizing...| 1521807867545|              1|
# |   Tapatio,Hot Sauce| 1521807858905|              1|
# |Chemin Du Soleil,...| 1521807865625|              1|
# |J. Lohr,Seven Oak...| 1521807865145|              1|
# |Cen-Tech,7 Functi...| 1521807861785|              1|
# |Honeywell,Power A...| 1521807865145|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
#
# +--------------------+--------------+---------------+
# |             product|timestamp_hour|unique_visitors|
# +--------------------+--------------+---------------+
# |Aveeno,Men's Afte...| 1521807875811|              1|
# |e.l.f.,Smudge Pot...| 1521807859491|              1|
# |Honeywell,Power A...| 1521807874371|              1|
# |Purity Farms,Orga...| 1521807873891|              1|
# |Colgate,Toothbrus...| 1521807871011|              1|
# |Trident,"White Gu...| 1521807864291|              1|
# |Kroger,Granulated...| 1521807866211|              1|
# |Cloud 9,Cutlery C...| 1521807873411|              1|
# |      Barilla,Rotini| 1521807867651|              1|
# |Botanics,Hydratin...| 1521807859971|              1|
# +--------------------+--------------+---------------+
# only showing top 10 rows
#
# root
#  |-- product: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- unique_visitors: long (nullable = false)
