# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from Activity import Activity
from activityByProduct import activityByProduct
from pyspark.streaming.kafka import KafkaUtils
import os
import time
from pyspark.sql import SQLContext
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ##### Environment setup

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--conf spark.ui.port=4040 --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.0.0,com.datastax.spark:spark-cassandra-connector_2.11:2.0.0-M3 pyspark-shell'

# %%
conf = SparkConf() \
    .setAppName("Streaming test") \
    .setMaster("local[2]") \
    .set("spark.cassandra.connection.host", "127.0.0.1")
sc = SparkContext(conf=conf) 
sqlcontext=SQLContext(sc)

# %%
ssc = StreamingContext(sc,2)

# %% [markdown]
# ##### Kafka with spark streaming

# %%
textDStream1 = KafkaUtils.createStream(ssc, 'localhost:2181', 'spark-streaming', {'data_pipeline':1})
textDStream = textDStream1.map(lambda x: x[1])

# %% [markdown]
# ##### Streaming

# %%
def subprocess(line):
    records = line.split("\t")
    if records[0] != "action" and len(records) == 7:
        return Activity(records[0],records[1],records[2],records[3],records[4],records[5],records[6])
    else:
        return None

# %%
def process(rdd):
    if not rdd.isEmpty():
        newRDD = rdd.map(subprocess)
    else:
        newRDD = None
    return newRDD

# %% [markdown]
# #### Transformaton

# %%
def transformation(inputDF):
    inputDF.createOrReplaceTempView("Activity")
    visitorsByProduct = sqlcontext.sql("SELECT product, timestamp_hour, COUNT(DISTINCT visitor) as unique_visitors FROM Activity GROUP BY product, timestamp_hour")
    activityByProduct = sqlcontext.sql("SELECT product, timestamp_hour, sum(case when action = 'purchase' then 1 else 0 end) as purchase_count, sum(case when action = 'add_to_cart' then 1 else 0 end) as add_to_cart_count, sum(case when action = 'page_view' then 1 else 0 end) as page_view_count from Activity group by product, timestamp_hour").cache()
    return visitorsByProduct,activityByProduct

# %%
def timestamp_conversion(timestamp):
        if timestamp is not None:
            return time.strftime('%Y-%m-%d', time.gmtime(int(timestamp)/1000))
        else:
            return "null null"

# %% [markdown]
# #### UDF for Time Conversion

# %%
time_udf = udf(timestamp_conversion,StringType())

# %% [markdown]
# #### Send streaming data to both hdfs and cassandra

# %%
def process_query(rdd):
    if not rdd.isEmpty():
        newDF=rdd.map(lambda x: (x, )).toDF()
        newDF2 = newDF.select('_1.*')     
     
        
        inputDF = newDF2.withColumn("timestamp_hour",time_udf(newDF2["timestamp_hour"]))
        
        print(inputDF.printSchema())
        print(inputDF.show(10, truncate=False))
        inputDF.write.partitionBy("timestamp_hour").mode("append").csv("hdfs://localhost:9000/kafka_spark",header=True)
        
        inputDF.createOrReplaceTempView("activity")
        print(inputDF.show(10, truncate=False))
        
        visitorsByProduct,activityByProduct=transformation(newDF2)
#         visitorsByProduct.write.format("org.apache.spark.sql.cassandra").mode('append').options(table="stream_visitors_by_product", keyspace="lambda").save()
#         activityByProduct.write.format("org.apache.spark.sql.cassandra").mode('append').options(table="stream_activity_by_product", keyspace="lambda").save()

# %% [markdown]
# ###### Start Streaming...

# %%
newDStream = textDStream.transform(process)

# %%
newDStream.foreachRDD(process_query)

# %%
ssc.start()

# %% [markdown]
# ##### Stop Streaming

# %%
# ssc.stop(stopSparkContext=False,stopGraceFully=True)
# Out:
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |Page-9  |Farmland,Lower Sodium Bacon                      |Internal|2018-03-26    |Visitor-95788 |
# |add_to_cart|Page-7 |        |Scrabble,Crossword Game                          |Google  |2018-03-26    |Visitor-897018|
# |page_view  |Page-7 |        |Comet,Comet With Bleach                          |Yahoo   |2018-03-26    |Visitor-264917|
# |page_view  |Page-7 |        |Google,Chromecast                                |Other   |2018-03-26    |Visitor-387608|
# |page_view  |Page-11|        |Bolla,Pinot Grigio                               |Facebook|2018-03-26    |Visitor-936429|
# |page_view  |Page-3 |Page-9  |Sanyo,Eneloop 4 AA Batteries and Charger         |Internal|2018-03-26    |Visitor-28994 |
# |page_view  |Page-0 |        |Saft Lingon,Lingonberry Drink Concentrate        |Google  |2018-03-26    |Visitor-152008|
# |page_view  |Page-14|        |OYO,Whiskey                                      |Bing    |2018-03-26    |Visitor-564482|
# |page_view  |Page-0 |        |J. Lohr,Seven Oaks Paso Robles Cabernet Sauvignon|Yahoo   |2018-03-26    |Visitor-507906|
# |page_view  |Page-7 |Page-8  |Orbit,Spearmint Sugarfree Gum                    |Internal|2018-03-26    |Visitor-705422|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |Page-9  |Farmland,Lower Sodium Bacon                      |Internal|2018-03-26    |Visitor-95788 |
# |add_to_cart|Page-7 |        |Scrabble,Crossword Game                          |Google  |2018-03-26    |Visitor-897018|
# |page_view  |Page-7 |        |Comet,Comet With Bleach                          |Yahoo   |2018-03-26    |Visitor-264917|
# |page_view  |Page-7 |        |Google,Chromecast                                |Other   |2018-03-26    |Visitor-387608|
# |page_view  |Page-11|        |Bolla,Pinot Grigio                               |Facebook|2018-03-26    |Visitor-936429|
# |page_view  |Page-3 |Page-9  |Sanyo,Eneloop 4 AA Batteries and Charger         |Internal|2018-03-26    |Visitor-28994 |
# |page_view  |Page-0 |        |Saft Lingon,Lingonberry Drink Concentrate        |Google  |2018-03-26    |Visitor-152008|
# |page_view  |Page-14|        |OYO,Whiskey                                      |Bing    |2018-03-26    |Visitor-564482|
# |page_view  |Page-0 |        |J. Lohr,Seven Oaks Paso Robles Cabernet Sauvignon|Yahoo   |2018-03-26    |Visitor-507906|
# |page_view  |Page-7 |Page-8  |Orbit,Spearmint Sugarfree Gum                    |Internal|2018-03-26    |Visitor-705422|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Avery,Permanent Reinforcement Labels          |Twitter |2018-03-26    |Visitor-621650|
# |add_to_cart|Page-0 |        |Parallax Inc.,Extension Cables & 3-Pin Headers|Bing    |2018-03-26    |Visitor-111446|
# |page_view  |Page-7 |        |Neutrogena,On-the-Spot Acne Treatment         |Direct  |2018-03-26    |Visitor-94235 |
# |page_view  |Page-14|        |Air Wick,Dual Action Spray                    |Google  |2018-03-26    |Visitor-455229|
# |page_view  |Page-12|        |Pond's,Dry Skin Cream                         |Google  |2018-03-26    |Visitor-845284|
# |page_view  |Page-4 |        |Kleenex,White Tissues                         |Other   |2018-03-26    |Visitor-887981|
# |page_view  |Page-12|        |Heinz,Distilled White Vinegar                 |Twitter |2018-03-26    |Visitor-358024|
# |page_view  |Page-10|        |Neutrogena,On-the-Spot Acne Treatment         |Yahoo   |2018-03-26    |Visitor-511295|
# |page_view  |Page-14|        |First Aid Beauty,Face Cleanser                |Other   |2018-03-26    |Visitor-893840|
# |page_view  |Page-4 |        |Neutrogena,On-the-Spot Acne Treatment         |Facebook|2018-03-26    |Visitor-705824|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Avery,Permanent Reinforcement Labels          |Twitter |2018-03-26    |Visitor-621650|
# |add_to_cart|Page-0 |        |Parallax Inc.,Extension Cables & 3-Pin Headers|Bing    |2018-03-26    |Visitor-111446|
# |page_view  |Page-7 |        |Neutrogena,On-the-Spot Acne Treatment         |Direct  |2018-03-26    |Visitor-94235 |
# |page_view  |Page-14|        |Air Wick,Dual Action Spray                    |Google  |2018-03-26    |Visitor-455229|
# |page_view  |Page-12|        |Pond's,Dry Skin Cream                         |Google  |2018-03-26    |Visitor-845284|
# |page_view  |Page-4 |        |Kleenex,White Tissues                         |Other   |2018-03-26    |Visitor-887981|
# |page_view  |Page-12|        |Heinz,Distilled White Vinegar                 |Twitter |2018-03-26    |Visitor-358024|
# |page_view  |Page-10|        |Neutrogena,On-the-Spot Acne Treatment         |Yahoo   |2018-03-26    |Visitor-511295|
# |page_view  |Page-14|        |First Aid Beauty,Face Cleanser                |Other   |2018-03-26    |Visitor-893840|
# |page_view  |Page-4 |        |Neutrogena,On-the-Spot Acne Treatment         |Facebook|2018-03-26    |Visitor-705824|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page  |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6|        |Clif Bar,Chocolate Almond Fudge Energy Bar              |Other   |2018-03-26    |Visitor-820160|
# |add_to_cart|Page-3|        |Glade,Clean Linen Air Freshener                         |Twitter |2018-03-26    |Visitor-759727|
# |page_view  |Page-8|        |Nature Made,D3 400 IU                                   |Facebook|2018-03-26    |Visitor-383408|
# |page_view  |Page-0|        |Ralphs,Plastic Wrap                                     |Facebook|2018-03-26    |Visitor-831022|
# |page_view  |Page-7|        |Banana Boat,Sport Performance- UVA/UVB protection SPF 30|Bing    |2018-03-26    |Visitor-704271|
# |page_view  |Page-9|        |Aveeno,Men's After Shave Lotion                         |Facebook|2018-03-26    |Visitor-930051|
# |page_view  |Page-0|        |Chobani,Greek Yogurt - Plain                            |Facebook|2018-03-26    |Visitor-446353|
# |page_view  |Page-6|        |Annie's,Rice Pasta and Extra Cheesy Cheddar Sauce       |Other   |2018-03-26    |Visitor-652949|
# |page_view  |Page-8|Page-14 |Jergens,Natural Glow                                    |Internal|2018-03-26    |Visitor-965997|
# |page_view  |Page-2|        |Clif Bar,Berry Pomegranate Chia Energy Bar              |Yahoo   |2018-03-26    |Visitor-310110|
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page  |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6|        |Clif Bar,Chocolate Almond Fudge Energy Bar              |Other   |2018-03-26    |Visitor-820160|
# |add_to_cart|Page-3|        |Glade,Clean Linen Air Freshener                         |Twitter |2018-03-26    |Visitor-759727|
# |page_view  |Page-8|        |Nature Made,D3 400 IU                                   |Facebook|2018-03-26    |Visitor-383408|
# |page_view  |Page-0|        |Ralphs,Plastic Wrap                                     |Facebook|2018-03-26    |Visitor-831022|
# |page_view  |Page-7|        |Banana Boat,Sport Performance- UVA/UVB protection SPF 30|Bing    |2018-03-26    |Visitor-704271|
# |page_view  |Page-9|        |Aveeno,Men's After Shave Lotion                         |Facebook|2018-03-26    |Visitor-930051|
# |page_view  |Page-0|        |Chobani,Greek Yogurt - Plain                            |Facebook|2018-03-26    |Visitor-446353|
# |page_view  |Page-6|        |Annie's,Rice Pasta and Extra Cheesy Cheddar Sauce       |Other   |2018-03-26    |Visitor-652949|
# |page_view  |Page-8|Page-14 |Jergens,Natural Glow                                    |Internal|2018-03-26    |Visitor-965997|
# |page_view  |Page-2|        |Clif Bar,Berry Pomegranate Chia Energy Bar              |Yahoo   |2018-03-26    |Visitor-310110|
# +-----------+------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-5 |        |Parallax Inc.,Extension Cables & 3-Pin Headers |Direct  |2018-03-26    |Visitor-610955|
# |add_to_cart|Page-13|        |Red Vines,Original Red Twists                  |Direct  |2018-03-26    |Visitor-538799|
# |page_view  |Page-3 |        |Botanics,Hydrating Day Cream All Bright SPF 15 |Twitter |2018-03-26    |Visitor-158506|
# |page_view  |Page-13|        |Band-Aid,Flexible Fabric Adhesive Bandages     |Bing    |2018-03-26    |Visitor-926184|
# |page_view  |Page-12|        |Kind,Thai Sweet Chili Almond Protein Bar       |Google  |2018-03-26    |Visitor-636657|
# |page_view  |Page-0 |        |Tropicana,Orange Juice with Calcium & Vitamin D|Facebook|2018-03-26    |Visitor-39911 |
# |purchase   |Page-2 |        |Harney & Sons,Spiced Black Holiday Tea         |Bing    |2018-03-26    |Visitor-311549|
# |page_view  |Page-1 |        |Gatorade,Fierce Grape                          |Yahoo   |2018-03-26    |Visitor-709392|
# |page_view  |Page-5 |        |Farmland,Lower Sodium Bacon                    |Google  |2018-03-26    |Visitor-971277|
# |page_view  |Page-6 |        |Air Wick,Dual Action Spray                     |Google  |2018-03-26    |Visitor-749196|
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-5 |        |Parallax Inc.,Extension Cables & 3-Pin Headers |Direct  |2018-03-26    |Visitor-610955|
# |add_to_cart|Page-13|        |Red Vines,Original Red Twists                  |Direct  |2018-03-26    |Visitor-538799|
# |page_view  |Page-3 |        |Botanics,Hydrating Day Cream All Bright SPF 15 |Twitter |2018-03-26    |Visitor-158506|
# |page_view  |Page-13|        |Band-Aid,Flexible Fabric Adhesive Bandages     |Bing    |2018-03-26    |Visitor-926184|
# |page_view  |Page-12|        |Kind,Thai Sweet Chili Almond Protein Bar       |Google  |2018-03-26    |Visitor-636657|
# |page_view  |Page-0 |        |Tropicana,Orange Juice with Calcium & Vitamin D|Facebook|2018-03-26    |Visitor-39911 |
# |purchase   |Page-2 |        |Harney & Sons,Spiced Black Holiday Tea         |Bing    |2018-03-26    |Visitor-311549|
# |page_view  |Page-1 |        |Gatorade,Fierce Grape                          |Yahoo   |2018-03-26    |Visitor-709392|
# |page_view  |Page-5 |        |Farmland,Lower Sodium Bacon                    |Google  |2018-03-26    |Visitor-971277|
# |page_view  |Page-6 |        |Air Wick,Dual Action Spray                     |Google  |2018-03-26    |Visitor-749196|
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                     |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |        |Band-Aid,Flexible Fabric Bandages           |Facebook|2018-03-26    |Visitor-492613|
# |add_to_cart|Page-13|        |Reynolds,Wrap                               |Other   |2018-03-26    |Visitor-666306|
# |page_view  |Page-6 |        |Cover Girl,Flamed Out Mascra                |Yahoo   |2018-03-26    |Visitor-858824|
# |page_view  |Page-0 |        |Avery,Heavy-Duty EZD Reference 3-Ring Binder|Other   |2018-03-26    |Visitor-280132|
# |page_view  |Page-6 |        |Westvleteren,Westvleteren XII               |Facebook|2018-03-26    |Visitor-371203|
# |page_view  |Page-9 |        |Gnarly Head,Cabernet Sauvignon              |Bing    |2018-03-26    |Visitor-454729|
# |page_view  |Page-3 |        |Stanley,9 Way Screwdriver                   |Twitter |2018-03-26    |Visitor-325478|
# |page_view  |Page-6 |Page-1  |Benadryl,Allergy                            |Internal|2018-03-26    |Visitor-6292  |
# |page_view  |Page-10|        |Safeway,Whole Black Pepper                  |Facebook|2018-03-26    |Visitor-844024|
# |page_view  |Page-4 |        |Pond's,Cold Cream Cleanser                  |Facebook|2018-03-26    |Visitor-369839|
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                     |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |        |Band-Aid,Flexible Fabric Bandages           |Facebook|2018-03-26    |Visitor-492613|
# |add_to_cart|Page-13|        |Reynolds,Wrap                               |Other   |2018-03-26    |Visitor-666306|
# |page_view  |Page-6 |        |Cover Girl,Flamed Out Mascra                |Yahoo   |2018-03-26    |Visitor-858824|
# |page_view  |Page-0 |        |Avery,Heavy-Duty EZD Reference 3-Ring Binder|Other   |2018-03-26    |Visitor-280132|
# |page_view  |Page-6 |        |Westvleteren,Westvleteren XII               |Facebook|2018-03-26    |Visitor-371203|
# |page_view  |Page-9 |        |Gnarly Head,Cabernet Sauvignon              |Bing    |2018-03-26    |Visitor-454729|
# |page_view  |Page-3 |        |Stanley,9 Way Screwdriver                   |Twitter |2018-03-26    |Visitor-325478|
# |page_view  |Page-6 |Page-1  |Benadryl,Allergy                            |Internal|2018-03-26    |Visitor-6292  |
# |page_view  |Page-10|        |Safeway,Whole Black Pepper                  |Facebook|2018-03-26    |Visitor-844024|
# |page_view  |Page-4 |        |Pond's,Cold Cream Cleanser                  |Facebook|2018-03-26    |Visitor-369839|
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                  |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |purchase   |Page-2 |        |Siggi's,"Icelandic Style Skyr, Blueberry"|Other   |2018-03-26    |Visitor-886143|
# |add_to_cart|Page-0 |Page-2  |Gnarly Head,Cabernet Sauvignon           |Internal|2018-03-26    |Visitor-141312|
# |page_view  |Page-3 |        |Menscience,Advanced Deodorant            |Twitter |2018-03-26    |Visitor-762450|
# |page_view  |Page-0 |        |Pond's,Dry Skin Cream                    |Yahoo   |2018-03-26    |Visitor-827229|
# |page_view  |Page-4 |        |SteamFast,Travel Steam Iron              |Twitter |2018-03-26    |Visitor-550860|
# |page_view  |Page-8 |        |Arduino,Yun                              |Bing    |2018-03-26    |Visitor-366753|
# |page_view  |Page-11|        |Reynolds,Slow Cooker Liners              |Bing    |2018-03-26    |Visitor-991334|
# |page_view  |Page-7 |        |Nature Made,D3 400 IU                    |Google  |2018-03-26    |Visitor-903760|
# |page_view  |Page-5 |        |Crisco,Pure Vegetable Oil                |Other   |2018-03-26    |Visitor-437194|
# |page_view  |Page-11|        |Avery,White Reinforcement Labels         |Twitter |2018-03-26    |Visitor-633340|
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                  |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |purchase   |Page-2 |        |Siggi's,"Icelandic Style Skyr, Blueberry"|Other   |2018-03-26    |Visitor-886143|
# |add_to_cart|Page-0 |Page-2  |Gnarly Head,Cabernet Sauvignon           |Internal|2018-03-26    |Visitor-141312|
# |page_view  |Page-3 |        |Menscience,Advanced Deodorant            |Twitter |2018-03-26    |Visitor-762450|
# |page_view  |Page-0 |        |Pond's,Dry Skin Cream                    |Yahoo   |2018-03-26    |Visitor-827229|
# |page_view  |Page-4 |        |SteamFast,Travel Steam Iron              |Twitter |2018-03-26    |Visitor-550860|
# |page_view  |Page-8 |        |Arduino,Yun                              |Bing    |2018-03-26    |Visitor-366753|
# |page_view  |Page-11|        |Reynolds,Slow Cooker Liners              |Bing    |2018-03-26    |Visitor-991334|
# |page_view  |Page-7 |        |Nature Made,D3 400 IU                    |Google  |2018-03-26    |Visitor-903760|
# |page_view  |Page-5 |        |Crisco,Pure Vegetable Oil                |Other   |2018-03-26    |Visitor-437194|
# |page_view  |Page-11|        |Avery,White Reinforcement Labels         |Twitter |2018-03-26    |Visitor-633340|
# +-----------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|        |Neutrogena,On-the-Spot Acne Treatment         |Yahoo   |2018-03-26    |Visitor-345304|
# |add_to_cart|Page-7 |Page-14 |Molton Brown,Re-Charge Black Pepper Body Wash |Internal|2018-03-26    |Visitor-633662|
# |page_view  |Page-3 |Page-1  |OYO,Whiskey                                   |Internal|2018-03-26    |Visitor-167635|
# |page_view  |Page-3 |        |Arduino,Yun                                   |Direct  |2018-03-26    |Visitor-875580|
# |page_view  |Page-8 |        |Molton Brown,Re-Charge Black Pepper Body Wash |Bing    |2018-03-26    |Visitor-304522|
# |page_view  |Page-13|        |Omega,J8004 Nutrition Center Juicer           |Yahoo   |2018-03-26    |Visitor-315519|
# |page_view  |Page-6 |        |l'Oreal,EverStrong Hydrate Shampoo            |Twitter |2018-03-26    |Visitor-703799|
# |page_view  |Page-6 |        |Clean & Clear,Acne Cleanser                   |Other   |2018-03-26    |Visitor-785079|
# |page_view  |Page-2 |        |Staples,Small Bind Clips                      |Twitter |2018-03-26    |Visitor-630850|
# |page_view  |Page-2 |        |Parallax Inc.,Extension Cables & 3-Pin Headers|Twitter |2018-03-26    |Visitor-623858|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|        |Neutrogena,On-the-Spot Acne Treatment         |Yahoo   |2018-03-26    |Visitor-345304|
# |add_to_cart|Page-7 |Page-14 |Molton Brown,Re-Charge Black Pepper Body Wash |Internal|2018-03-26    |Visitor-633662|
# |page_view  |Page-3 |Page-1  |OYO,Whiskey                                   |Internal|2018-03-26    |Visitor-167635|
# |page_view  |Page-3 |        |Arduino,Yun                                   |Direct  |2018-03-26    |Visitor-875580|
# |page_view  |Page-8 |        |Molton Brown,Re-Charge Black Pepper Body Wash |Bing    |2018-03-26    |Visitor-304522|
# |page_view  |Page-13|        |Omega,J8004 Nutrition Center Juicer           |Yahoo   |2018-03-26    |Visitor-315519|
# |page_view  |Page-6 |        |l'Oreal,EverStrong Hydrate Shampoo            |Twitter |2018-03-26    |Visitor-703799|
# |page_view  |Page-6 |        |Clean & Clear,Acne Cleanser                   |Other   |2018-03-26    |Visitor-785079|
# |page_view  |Page-2 |        |Staples,Small Bind Clips                      |Twitter |2018-03-26    |Visitor-630850|
# |page_view  |Page-2 |        |Parallax Inc.,Extension Cables & 3-Pin Headers|Twitter |2018-03-26    |Visitor-623858|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase |Page-12|        |Nestle,Leche Condensada                         |Facebook|2018-03-26    |Visitor-192633|
# |page_view|Page-4 |        |e.l.f.,Eyebrow Kit- Darl                        |Other   |2018-03-26    |Visitor-622935|
# |page_view|Page-8 |        |Garnier Fructis Style,Pure Clean Finishing Paste|Facebook|2018-03-26    |Visitor-529811|
# |page_view|Page-8 |        |Spectrum Naturals,Peanut Oil                    |Twitter |2018-03-26    |Visitor-237542|
# |page_view|Page-7 |        |Tropicana,Orange Juice with Calcium & Vitamin D |Other   |2018-03-26    |Visitor-768365|
# |page_view|Page-7 |        |Biotene,Dry Mouth  Oral Rinse                   |Twitter |2018-03-26    |Visitor-872599|
# |purchase |Page-14|Page-1  |California Pizza Kitchen,Sicilian Recipe Pizza  |Internal|2018-03-26    |Visitor-450004|
# |page_view|Page-1 |        |Secret,pH Balanced - Unscented                  |Google  |2018-03-26    |Visitor-790452|
# |page_view|Page-1 |Page-11 |Glade,Clean Linen Air Freshener                 |Internal|2018-03-26    |Visitor-538623|
# |page_view|Page-14|        |David's Tea,Bubbie's Baklava Oolong Tea         |Twitter |2018-03-26    |Visitor-255124|
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase |Page-12|        |Nestle,Leche Condensada                         |Facebook|2018-03-26    |Visitor-192633|
# |page_view|Page-4 |        |e.l.f.,Eyebrow Kit- Darl                        |Other   |2018-03-26    |Visitor-622935|
# |page_view|Page-8 |        |Garnier Fructis Style,Pure Clean Finishing Paste|Facebook|2018-03-26    |Visitor-529811|
# |page_view|Page-8 |        |Spectrum Naturals,Peanut Oil                    |Twitter |2018-03-26    |Visitor-237542|
# |page_view|Page-7 |        |Tropicana,Orange Juice with Calcium & Vitamin D |Other   |2018-03-26    |Visitor-768365|
# |page_view|Page-7 |        |Biotene,Dry Mouth  Oral Rinse                   |Twitter |2018-03-26    |Visitor-872599|
# |purchase |Page-14|Page-1  |California Pizza Kitchen,Sicilian Recipe Pizza  |Internal|2018-03-26    |Visitor-450004|
# |page_view|Page-1 |        |Secret,pH Balanced - Unscented                  |Google  |2018-03-26    |Visitor-790452|
# |page_view|Page-1 |Page-11 |Glade,Clean Linen Air Freshener                 |Internal|2018-03-26    |Visitor-538623|
# |page_view|Page-14|        |David's Tea,Bubbie's Baklava Oolong Tea         |Twitter |2018-03-26    |Visitor-255124|
# +---------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0 |        |Blizzard,Starcraft II: Wings of Liberty       |Bing    |2018-03-26    |Visitor-479917|
# |add_to_cart|Page-4 |        |CVS Pharmacy,200mg Ibuprofen Capsules         |Other   |2018-03-26    |Visitor-734065|
# |page_view  |Page-13|        |California Pizza Kitchen,Sicilian Recipe Pizza|Other   |2018-03-26    |Visitor-662143|
# |page_view  |Page-5 |        |Clorox,Disinfecting Wipes                     |Facebook|2018-03-26    |Visitor-871065|
# |page_view  |Page-7 |        |Dust Destroyer,Compressed-Gas Duster          |Google  |2018-03-26    |Visitor-733959|
# |page_view  |Page-4 |        |Glade,Clean Linen Air Freshener               |Twitter |2018-03-26    |Visitor-362258|
# |page_view  |Page-9 |        |Rosewill,Hard Drive Docking                   |Other   |2018-03-26    |Visitor-230959|
# |page_view  |Page-6 |        |Band-Aid,Flexible Fabric Adhesive Bandages    |Direct  |2018-03-26    |Visitor-717112|
# |page_view  |Page-9 |        |Lipton,Pure Green Tea                         |Facebook|2018-03-26    |Visitor-48358 |
# |page_view  |Page-8 |Page-6  |Arm & Hammer,Ultra Max Deodorant              |Internal|2018-03-26    |Visitor-729677|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0 |        |Blizzard,Starcraft II: Wings of Liberty       |Bing    |2018-03-26    |Visitor-479917|
# |add_to_cart|Page-4 |        |CVS Pharmacy,200mg Ibuprofen Capsules         |Other   |2018-03-26    |Visitor-734065|
# |page_view  |Page-13|        |California Pizza Kitchen,Sicilian Recipe Pizza|Other   |2018-03-26    |Visitor-662143|
# |page_view  |Page-5 |        |Clorox,Disinfecting Wipes                     |Facebook|2018-03-26    |Visitor-871065|
# |page_view  |Page-7 |        |Dust Destroyer,Compressed-Gas Duster          |Google  |2018-03-26    |Visitor-733959|
# |page_view  |Page-4 |        |Glade,Clean Linen Air Freshener               |Twitter |2018-03-26    |Visitor-362258|
# |page_view  |Page-9 |        |Rosewill,Hard Drive Docking                   |Other   |2018-03-26    |Visitor-230959|
# |page_view  |Page-6 |        |Band-Aid,Flexible Fabric Adhesive Bandages    |Direct  |2018-03-26    |Visitor-717112|
# |page_view  |Page-9 |        |Lipton,Pure Green Tea                         |Facebook|2018-03-26    |Visitor-48358 |
# |page_view  |Page-8 |Page-6  |Arm & Hammer,Ultra Max Deodorant              |Internal|2018-03-26    |Visitor-729677|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6 |        |Grandma's Seasonings,Chili Powder                |Twitter |2018-03-26    |Visitor-521289|
# |add_to_cart|Page-10|        |Mr. Clean,Magic Eraser                           |Facebook|2018-03-26    |Visitor-562921|
# |page_view  |Page-11|        |Scotch,Super 33+ Vinyl Electric Tape             |Yahoo   |2018-03-26    |Visitor-521940|
# |page_view  |Page-8 |        |Colgate,Toothbrush Value Pack                    |Other   |2018-03-26    |Visitor-617502|
# |page_view  |Page-7 |        |Purity Farms,Organic Ghee                        |Google  |2018-03-26    |Visitor-588270|
# |page_view  |Page-14|        |Ralphs,Nice 'n Elegant Spoons                    |Facebook|2018-03-26    |Visitor-130040|
# |page_view  |Page-8 |Page-2  |Kellogg's,Corn Flakes                            |Internal|2018-03-26    |Visitor-983651|
# |page_view  |Page-2 |        |J. Lohr,Seven Oaks Paso Robles Cabernet Sauvignon|Twitter |2018-03-26    |Visitor-59312 |
# |page_view  |Page-3 |        |Pond's,Cold Cream Cleanser                       |Other   |2018-03-26    |Visitor-409339|
# |page_view  |Page-3 |        |Staples,Small Bind Clips                         |Twitter |2018-03-26    |Visitor-767437|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6 |        |Grandma's Seasonings,Chili Powder                |Twitter |2018-03-26    |Visitor-521289|
# |add_to_cart|Page-10|        |Mr. Clean,Magic Eraser                           |Facebook|2018-03-26    |Visitor-562921|
# |page_view  |Page-11|        |Scotch,Super 33+ Vinyl Electric Tape             |Yahoo   |2018-03-26    |Visitor-521940|
# |page_view  |Page-8 |        |Colgate,Toothbrush Value Pack                    |Other   |2018-03-26    |Visitor-617502|
# |page_view  |Page-7 |        |Purity Farms,Organic Ghee                        |Google  |2018-03-26    |Visitor-588270|
# |page_view  |Page-14|        |Ralphs,Nice 'n Elegant Spoons                    |Facebook|2018-03-26    |Visitor-130040|
# |page_view  |Page-8 |Page-2  |Kellogg's,Corn Flakes                            |Internal|2018-03-26    |Visitor-983651|
# |page_view  |Page-2 |        |J. Lohr,Seven Oaks Paso Robles Cabernet Sauvignon|Twitter |2018-03-26    |Visitor-59312 |
# |page_view  |Page-3 |        |Pond's,Cold Cream Cleanser                       |Other   |2018-03-26    |Visitor-409339|
# |page_view  |Page-3 |        |Staples,Small Bind Clips                         |Twitter |2018-03-26    |Visitor-767437|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-12|        |Lysol,Bathroom Cleaner with Hydrogen Peroxide |Twitter |2018-03-26    |Visitor-475486|
# |add_to_cart|Page-12|        |Knorr,Salsa Lista Pizza                       |Other   |2018-03-26    |Visitor-131373|
# |page_view  |Page-2 |Page-8  |Jolen,Creme Bleach - Lightens Excess Dark Hair|Internal|2018-03-26    |Visitor-69951 |
# |page_view  |Page-9 |        |Edge,Sensitive Skin Shaving Gel with Aloe     |Twitter |2018-03-26    |Visitor-456997|
# |page_view  |Page-14|Page-7  |All,"Mighty Pacs, Free Clear"                 |Internal|2018-03-26    |Visitor-312896|
# |page_view  |Page-13|        |Chemin Du Soleil,Chardonnay                   |Direct  |2018-03-26    |Visitor-245817|
# |page_view  |Page-6 |        |Ancient Harvest,Quinoa Rotelle                |Facebook|2018-03-26    |Visitor-250254|
# |page_view  |Page-5 |        |Mr. Clean,Magic Eraser                        |Twitter |2018-03-26    |Visitor-497032|
# |page_view  |Page-4 |        |Opti-Free,Pure Moist Contact Solution         |Yahoo   |2018-03-26    |Visitor-446130|
# |page_view  |Page-14|        |Axe,Axe Anarchy for Her                       |Yahoo   |2018-03-26    |Visitor-195450|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-12|        |Lysol,Bathroom Cleaner with Hydrogen Peroxide |Twitter |2018-03-26    |Visitor-475486|
# |add_to_cart|Page-12|        |Knorr,Salsa Lista Pizza                       |Other   |2018-03-26    |Visitor-131373|
# |page_view  |Page-2 |Page-8  |Jolen,Creme Bleach - Lightens Excess Dark Hair|Internal|2018-03-26    |Visitor-69951 |
# |page_view  |Page-9 |        |Edge,Sensitive Skin Shaving Gel with Aloe     |Twitter |2018-03-26    |Visitor-456997|
# |page_view  |Page-14|Page-7  |All,"Mighty Pacs, Free Clear"                 |Internal|2018-03-26    |Visitor-312896|
# |page_view  |Page-13|        |Chemin Du Soleil,Chardonnay                   |Direct  |2018-03-26    |Visitor-245817|
# |page_view  |Page-6 |        |Ancient Harvest,Quinoa Rotelle                |Facebook|2018-03-26    |Visitor-250254|
# |page_view  |Page-5 |        |Mr. Clean,Magic Eraser                        |Twitter |2018-03-26    |Visitor-497032|
# |page_view  |Page-4 |        |Opti-Free,Pure Moist Contact Solution         |Yahoo   |2018-03-26    |Visitor-446130|
# |page_view  |Page-14|        |Axe,Axe Anarchy for Her                       |Yahoo   |2018-03-26    |Visitor-195450|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-1 |        |CVS Total Home,"Aluminum Foil, Heavy Duty"      |Yahoo   |2018-03-26    |Visitor-278750|
# |add_to_cart|Page-13|        |Fernet-Branca,Liqueur                           |Bing    |2018-03-26    |Visitor-154094|
# |page_view  |Page-7 |        |Trader Joe's,Curry Powder                       |Other   |2018-03-26    |Visitor-744663|
# |page_view  |Page-3 |        |Reynolds,Parchment Paper                        |Twitter |2018-03-26    |Visitor-497601|
# |page_view  |Page-2 |Page-12 |Scott,One Ply Bathroom Tissue                   |Internal|2018-03-26    |Visitor-725882|
# |page_view  |Page-7 |        |Natural Grooming by Herban Cowboy,Dusk Deodorant|Yahoo   |2018-03-26    |Visitor-396068|
# |page_view  |Page-6 |Page-14 |Crest,Pro-Health Clean Mint Toothpaste          |Internal|2018-03-26    |Visitor-273846|
# |page_view  |Page-6 |        |Neutrogena,Alcohol-Free Toner                   |Twitter |2018-03-26    |Visitor-484029|
# |page_view  |Page-2 |        |Coop,Tiefkühlbeutel mit Druckverschluss         |Twitter |2018-03-26    |Visitor-115173|
# |page_view  |Page-11|        |American Crew,Fiber                             |Yahoo   |2018-03-26    |Visitor-403929|
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-1 |        |CVS Total Home,"Aluminum Foil, Heavy Duty"      |Yahoo   |2018-03-26    |Visitor-278750|
# |add_to_cart|Page-13|        |Fernet-Branca,Liqueur                           |Bing    |2018-03-26    |Visitor-154094|
# |page_view  |Page-7 |        |Trader Joe's,Curry Powder                       |Other   |2018-03-26    |Visitor-744663|
# |page_view  |Page-3 |        |Reynolds,Parchment Paper                        |Twitter |2018-03-26    |Visitor-497601|
# |page_view  |Page-2 |Page-12 |Scott,One Ply Bathroom Tissue                   |Internal|2018-03-26    |Visitor-725882|
# |page_view  |Page-7 |        |Natural Grooming by Herban Cowboy,Dusk Deodorant|Yahoo   |2018-03-26    |Visitor-396068|
# |page_view  |Page-6 |Page-14 |Crest,Pro-Health Clean Mint Toothpaste          |Internal|2018-03-26    |Visitor-273846|
# |page_view  |Page-6 |        |Neutrogena,Alcohol-Free Toner                   |Twitter |2018-03-26    |Visitor-484029|
# |page_view  |Page-2 |        |Coop,Tiefkühlbeutel mit Druckverschluss         |Twitter |2018-03-26    |Visitor-115173|
# |page_view  |Page-11|        |American Crew,Fiber                             |Yahoo   |2018-03-26    |Visitor-403929|
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |        |Nivea,Sensitive Men's Shaving Gel                       |Twitter |2018-03-26    |Visitor-967320|
# |add_to_cart|Page-14|        |Pond's,Dry Skin Cream                                   |Bing    |2018-03-26    |Visitor-98042 |
# |page_view  |Page-14|        |Meijer,Vitamin C 500 mg                                 |Twitter |2018-03-26    |Visitor-902442|
# |page_view  |Page-14|        |Neutrogena,On-the-Spot Acne Treatment                   |Other   |2018-03-26    |Visitor-502764|
# |page_view  |Page-5 |        |Banquet,Brown 'N Serve Original Sausage Links           |Bing    |2018-03-26    |Visitor-83451 |
# |page_view  |Page-6 |        |Dust Destroyer,Compressed-Gas Duster                    |Bing    |2018-03-26    |Visitor-656964|
# |page_view  |Page-14|Page-0  |Hot Shot,Flying Insect Killer                           |Internal|2018-03-26    |Visitor-194211|
# |page_view  |Page-5 |        |David's Tea,Chocolate Rocket Mate Tea                   |Yahoo   |2018-03-26    |Visitor-693346|
# |page_view  |Page-9 |        |Sharpie,Fine Permanent Marker                           |Bing    |2018-03-26    |Visitor-361894|
# |page_view  |Page-1 |        |Kleenex,2-Ply White Tissues (208 × 213 mm/ 8.2 × 8.4 in)|Yahoo   |2018-03-26    |Visitor-178163|
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |        |Nivea,Sensitive Men's Shaving Gel                       |Twitter |2018-03-26    |Visitor-967320|
# |add_to_cart|Page-14|        |Pond's,Dry Skin Cream                                   |Bing    |2018-03-26    |Visitor-98042 |
# |page_view  |Page-14|        |Meijer,Vitamin C 500 mg                                 |Twitter |2018-03-26    |Visitor-902442|
# |page_view  |Page-14|        |Neutrogena,On-the-Spot Acne Treatment                   |Other   |2018-03-26    |Visitor-502764|
# |page_view  |Page-5 |        |Banquet,Brown 'N Serve Original Sausage Links           |Bing    |2018-03-26    |Visitor-83451 |
# |page_view  |Page-6 |        |Dust Destroyer,Compressed-Gas Duster                    |Bing    |2018-03-26    |Visitor-656964|
# |page_view  |Page-14|Page-0  |Hot Shot,Flying Insect Killer                           |Internal|2018-03-26    |Visitor-194211|
# |page_view  |Page-5 |        |David's Tea,Chocolate Rocket Mate Tea                   |Yahoo   |2018-03-26    |Visitor-693346|
# |page_view  |Page-9 |        |Sharpie,Fine Permanent Marker                           |Bing    |2018-03-26    |Visitor-361894|
# |page_view  |Page-1 |        |Kleenex,2-Ply White Tissues (208 × 213 mm/ 8.2 × 8.4 in)|Yahoo   |2018-03-26    |Visitor-178163|
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
# ...
# only showing top 10 rows
#
# None
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                      |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-3 |Page-7  |Safeway Kitchens,Clover Honey                |Internal|2018-03-26    |Visitor-169128|
# |add_to_cart|Page-2 |        |Andersen's,Creamy Soup Split Pea             |Twitter |2018-03-26    |Visitor-875431|
# |page_view  |Page-4 |        |Nivea,Original Moisture Body Lotion          |Twitter |2018-03-26    |Visitor-208485|
# |page_view  |Page-7 |Page-8  |Kroger,Granulated Sugar                      |Internal|2018-03-26    |Visitor-360287|
# |page_view  |Page-9 |        |Arm & Hammer,Ultra Max Deodorant             |Direct  |2018-03-26    |Visitor-327239|
# |page_view  |Page-1 |Page-12 |CVS Total Home,"Aluminum Foil, Heavy Duty"   |Internal|2018-03-26    |Visitor-280397|
# |page_view  |Page-5 |        |Trader Joe's,Curry Powder                    |Bing    |2018-03-26    |Visitor-705098|
# |page_view  |Page-6 |        |Ancient Harvest,Quinoa Rotelle               |Yahoo   |2018-03-26    |Visitor-464320|
# |page_view  |Page-7 |        |Glad,Odor Shield Tall Kitchen Drawstring Bags|Other   |2018-03-26    |Visitor-201483|
# |page_view  |Page-11|        |Simple Truth Organic,Baby Arugula            |Direct  |2018-03-26    |Visitor-391939|
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|        |Barilla,Rotini                                |Twitter |2018-03-26    |Visitor-749682|
# |add_to_cart|Page-0 |        |Bolla,Pinot Grigio                            |Google  |2018-03-26    |Visitor-410638|
# |page_view  |Page-7 |        |Trader Joe's,Curry Powder                     |Other   |2018-03-26    |Visitor-529770|
# |page_view  |Page-8 |        |Disney,Tangled (DVD)                          |Yahoo   |2018-03-26    |Visitor-677201|
# |page_view  |Page-4 |        |Botanics,Hydrating Day Cream All Bright SPF 15|Twitter |2018-03-26    |Visitor-713438|
# |page_view  |Page-2 |        |Charmin,Ultra Soft                            |Direct  |2018-03-26    |Visitor-670893|
# |page_view  |Page-11|        |Cover Girl,Flamed Out Mascra                  |Facebook|2018-03-26    |Visitor-748734|
# |page_view  |Page-7 |        |Wexford,College Ruled Composition Book        |Direct  |2018-03-26    |Visitor-930391|
# |page_view  |Page-12|        |Palmolive,Original Dish Liquid                |Twitter |2018-03-26    |Visitor-793737|
# |page_view  |Page-2 |        |Gillette,Arctic Ice Clear Gel Deodorant       |Direct  |2018-03-26    |Visitor-830858|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|        |Barilla,Rotini                                |Twitter |2018-03-26    |Visitor-749682|
# |add_to_cart|Page-0 |        |Bolla,Pinot Grigio                            |Google  |2018-03-26    |Visitor-410638|
# |page_view  |Page-7 |        |Trader Joe's,Curry Powder                     |Other   |2018-03-26    |Visitor-529770|
# |page_view  |Page-8 |        |Disney,Tangled (DVD)                          |Yahoo   |2018-03-26    |Visitor-677201|
# |page_view  |Page-4 |        |Botanics,Hydrating Day Cream All Bright SPF 15|Twitter |2018-03-26    |Visitor-713438|
# |page_view  |Page-2 |        |Charmin,Ultra Soft                            |Direct  |2018-03-26    |Visitor-670893|
# |page_view  |Page-11|        |Cover Girl,Flamed Out Mascra                  |Facebook|2018-03-26    |Visitor-748734|
# |page_view  |Page-7 |        |Wexford,College Ruled Composition Book        |Direct  |2018-03-26    |Visitor-930391|
# |page_view  |Page-12|        |Palmolive,Original Dish Liquid                |Twitter |2018-03-26    |Visitor-793737|
# |page_view  |Page-2 |        |Gillette,Arctic Ice Clear Gel Deodorant       |Direct  |2018-03-26    |Visitor-830858|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                  |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |purchase |Page-0 |        |Kroger,2% Milk                           |Direct  |2018-03-26    |Visitor-574615|
# |page_view|Page-9 |        |Gillette,Arctic Ice Clear Gel Deodorant  |Google  |2018-03-26    |Visitor-940004|
# |page_view|Page-4 |Page-3  |Jergens,Natural Glow                     |Internal|2018-03-26    |Visitor-437278|
# |page_view|Page-8 |        |Nivea,Sensitive Men's Shaving Gel        |Twitter |2018-03-26    |Visitor-72534 |
# |page_view|Page-14|        |Sharpie,Fine Permanent Marker            |Bing    |2018-03-26    |Visitor-954085|
# |page_view|Page-7 |        |Edge,Sensitive Skin Shaving Gel with Aloe|Direct  |2018-03-26    |Visitor-507970|
# |page_view|Page-14|        |Pedifix,Arch Bandage                     |Yahoo   |2018-03-26    |Visitor-731358|
# |page_view|Page-10|Page-6  |Meijer,Vitamin C 500 mg                  |Internal|2018-03-26    |Visitor-213969|
# |page_view|Page-3 |        |Pereg,Organic Quinoa                     |Other   |2018-03-26    |Visitor-776893|
# |page_view|Page-9 |        |Community,Season 2 DVDs                  |Other   |2018-03-26    |Visitor-583424|
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                  |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# |purchase |Page-0 |        |Kroger,2% Milk                           |Direct  |2018-03-26    |Visitor-574615|
# |page_view|Page-9 |        |Gillette,Arctic Ice Clear Gel Deodorant  |Google  |2018-03-26    |Visitor-940004|
# |page_view|Page-4 |Page-3  |Jergens,Natural Glow                     |Internal|2018-03-26    |Visitor-437278|
# |page_view|Page-8 |        |Nivea,Sensitive Men's Shaving Gel        |Twitter |2018-03-26    |Visitor-72534 |
# |page_view|Page-14|        |Sharpie,Fine Permanent Marker            |Bing    |2018-03-26    |Visitor-954085|
# |page_view|Page-7 |        |Edge,Sensitive Skin Shaving Gel with Aloe|Direct  |2018-03-26    |Visitor-507970|
# |page_view|Page-14|        |Pedifix,Arch Bandage                     |Yahoo   |2018-03-26    |Visitor-731358|
# |page_view|Page-10|Page-6  |Meijer,Vitamin C 500 mg                  |Internal|2018-03-26    |Visitor-213969|
# |page_view|Page-3 |        |Pereg,Organic Quinoa                     |Other   |2018-03-26    |Visitor-776893|
# |page_view|Page-9 |        |Community,Season 2 DVDs                  |Other   |2018-03-26    |Visitor-583424|
# +---------+-------+--------+-----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                     |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0 |        |CVS Pharmacy,91% Isopropyl Alcohol          |Other   |2018-03-26    |Visitor-836550|
# |add_to_cart|Page-0 |        |Sol Republic,JAX Headphones                 |Twitter |2018-03-26    |Visitor-232579|
# |page_view  |Page-13|        |Axe,Axe Anarchy for Her                     |Google  |2018-03-26    |Visitor-591479|
# |page_view  |Page-3 |        |Crest,Pro-Health Clean Mint Toothpaste      |Other   |2018-03-26    |Visitor-352904|
# |page_view  |Page-3 |        |Vicks,DayQuil Severe Cold & Flu             |Direct  |2018-03-26    |Visitor-502646|
# |page_view  |Page-5 |        |Google,Chromecast                           |Other   |2018-03-26    |Visitor-441350|
# |page_view  |Page-13|Page-4  |Disney,Tangled (DVD)                        |Internal|2018-03-26    |Visitor-707325|
# |page_view  |Page-6 |        |Wholesome Kitchen,Farro and Garden Vegetable|Facebook|2018-03-26    |Visitor-207894|
# |page_view  |Page-6 |        |Omega,J8004 Nutrition Center Juicer         |Facebook|2018-03-26    |Visitor-226915|
# |page_view  |Page-3 |        |Staples,Small Bind Clips                    |Google  |2018-03-26    |Visitor-225838|
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                     |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0 |        |CVS Pharmacy,91% Isopropyl Alcohol          |Other   |2018-03-26    |Visitor-836550|
# |add_to_cart|Page-0 |        |Sol Republic,JAX Headphones                 |Twitter |2018-03-26    |Visitor-232579|
# |page_view  |Page-13|        |Axe,Axe Anarchy for Her                     |Google  |2018-03-26    |Visitor-591479|
# |page_view  |Page-3 |        |Crest,Pro-Health Clean Mint Toothpaste      |Other   |2018-03-26    |Visitor-352904|
# |page_view  |Page-3 |        |Vicks,DayQuil Severe Cold & Flu             |Direct  |2018-03-26    |Visitor-502646|
# |page_view  |Page-5 |        |Google,Chromecast                           |Other   |2018-03-26    |Visitor-441350|
# |page_view  |Page-13|Page-4  |Disney,Tangled (DVD)                        |Internal|2018-03-26    |Visitor-707325|
# |page_view  |Page-6 |        |Wholesome Kitchen,Farro and Garden Vegetable|Facebook|2018-03-26    |Visitor-207894|
# |page_view  |Page-6 |        |Omega,J8004 Nutrition Center Juicer         |Facebook|2018-03-26    |Visitor-226915|
# |page_view  |Page-3 |        |Staples,Small Bind Clips                    |Google  |2018-03-26    |Visitor-225838|
# +-----------+-------+--------+--------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                      |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-1 |        |Gunnar,Vayper Onyx Advanced Gaming Eyewear   |Bing    |2018-03-26    |Visitor-150340|
# |add_to_cart|Page-9 |        |Orbit,Spearmint Sugarfree Gum                |Facebook|2018-03-26    |Visitor-43039 |
# |page_view  |Page-12|Page-10 |Arduino,Yun                                  |Internal|2018-03-26    |Visitor-345411|
# |page_view  |Page-12|Page-6  |Band-Aid,Flexible Fabric Adhesive Bandages   |Internal|2018-03-26    |Visitor-401599|
# |page_view  |Page-3 |        |Kroger,Dry Roasted Unsalted Peanuts          |Other   |2018-03-26    |Visitor-561841|
# |page_view  |Page-11|        |Lysol,Bathroom Cleaner with Hydrogen Peroxide|Facebook|2018-03-26    |Visitor-483112|
# |page_view  |Page-6 |        |Purity Farms,Organic Ghee                    |Direct  |2018-03-26    |Visitor-987639|
# |page_view  |Page-7 |        |Dove,Clean Comfort Deodorant                 |Twitter |2018-03-26    |Visitor-827870|
# |page_view  |Page-14|        |Sharpie,Ultra Fine Permanent Marker          |Yahoo   |2018-03-26    |Visitor-135099|
# |page_view  |Page-2 |        |Pentel,Super Hi-Polymer Lead 0.7             |Facebook|2018-03-26    |Visitor-222149|
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                      |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-1 |        |Gunnar,Vayper Onyx Advanced Gaming Eyewear   |Bing    |2018-03-26    |Visitor-150340|
# |add_to_cart|Page-9 |        |Orbit,Spearmint Sugarfree Gum                |Facebook|2018-03-26    |Visitor-43039 |
# |page_view  |Page-12|Page-10 |Arduino,Yun                                  |Internal|2018-03-26    |Visitor-345411|
# |page_view  |Page-12|Page-6  |Band-Aid,Flexible Fabric Adhesive Bandages   |Internal|2018-03-26    |Visitor-401599|
# |page_view  |Page-3 |        |Kroger,Dry Roasted Unsalted Peanuts          |Other   |2018-03-26    |Visitor-561841|
# |page_view  |Page-11|        |Lysol,Bathroom Cleaner with Hydrogen Peroxide|Facebook|2018-03-26    |Visitor-483112|
# |page_view  |Page-6 |        |Purity Farms,Organic Ghee                    |Direct  |2018-03-26    |Visitor-987639|
# |page_view  |Page-7 |        |Dove,Clean Comfort Deodorant                 |Twitter |2018-03-26    |Visitor-827870|
# |page_view  |Page-14|        |Sharpie,Ultra Fine Permanent Marker          |Yahoo   |2018-03-26    |Visitor-135099|
# |page_view  |Page-2 |        |Pentel,Super Hi-Polymer Lead 0.7             |Facebook|2018-03-26    |Visitor-222149|
# +-----------+-------+--------+---------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
