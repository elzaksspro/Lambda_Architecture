# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from Activity import Activity
from activityByProduct import activityByProduct
from pyspark.streaming.kafka import KafkaUtils
import os
import time
from pyspark.sql import SQLContext
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ##### Environment setup

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--conf spark.ui.port=4040 --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.0.0,com.datastax.spark:spark-cassandra-connector_2.11:2.0.0-M3 pyspark-shell'

# %%
conf = SparkConf() \
    .setAppName("Streaming test") \
    .setMaster("local[2]") \
    .set("spark.cassandra.connection.host", "127.0.0.1")
sc = SparkContext(conf=conf) 
sqlcontext=SQLContext(sc)

# %%
ssc = StreamingContext(sc,2)

# %% [markdown]
# ##### Kafka with spark streaming

# %%
textDStream1 = KafkaUtils.createStream(ssc, 'localhost:2181', 'spark-streaming', {'data_pipeline':1})
textDStream = textDStream1.map(lambda x: x[1])

# %% [markdown]
# ##### Streaming

# %%
def subprocess(line):
    records = line.split("\t")
    if records[0] != "action" and len(records) == 7:
        return Activity(records[0],records[1],records[2],records[3],records[4],records[5],records[6])
    else:
        return None

# %%
def process(rdd):
    if not rdd.isEmpty():
        newRDD = rdd.map(subprocess)
    else:
        newRDD = None
    return newRDD

# %% [markdown]
# #### Transformaton

# %%
def transformation(inputDF):
    inputDF.createOrReplaceTempView("Activity")
    visitorsByProduct = sqlcontext.sql("SELECT product, timestamp_hour, COUNT(DISTINCT visitor) as unique_visitors FROM Activity GROUP BY product, timestamp_hour")
    activityByProduct = sqlcontext.sql("SELECT product, timestamp_hour, sum(case when action = 'purchase' then 1 else 0 end) as purchase_count, sum(case when action = 'add_to_cart' then 1 else 0 end) as add_to_cart_count, sum(case when action = 'page_view' then 1 else 0 end) as page_view_count from Activity group by product, timestamp_hour").cache()
    return visitorsByProduct,activityByProduct

# %%
def timestamp_conversion(timestamp):
        if timestamp is not None:
            return time.strftime('%Y-%m-%d', time.gmtime(int(timestamp)/1000))
        else:
            return "null null"

# %% [markdown]
# #### UDF for Time Conversion

# %%
time_udf = udf(timestamp_conversion,StringType())

# %% [markdown]
# #### Send streaming data to both hdfs and cassandra

# %%
def process_query(rdd):
    if not rdd.isEmpty():
        newDF=rdd.map(lambda x: (x, )).toDF()
        newDF2 = newDF.select('_1.*')     
     
        
        inputDF = newDF2.withColumn("timestamp_hour",time_udf(newDF2["timestamp_hour"]))
        
        print(newDF2.printSchema())
        print(newDF2.show(10, truncate=False))
        inputDF.write.partitionBy("timestamp_hour").mode("append").csv("hdfs://localhost:9000/kafka_spark",header=True)
        
        inputDF.createOrReplaceTempView("activity")
        print(inputDF.show(10, truncate=False))
        
        visitorsByProduct,activityByProduct=transformation(newDF2)
#         visitorsByProduct.write.format("org.apache.spark.sql.cassandra").mode('append').options(table="stream_visitors_by_product", keyspace="lambda").save()
#         activityByProduct.write.format("org.apache.spark.sql.cassandra").mode('append').options(table="stream_activity_by_product", keyspace="lambda").save()

# %% [markdown]
# ###### Start Streaming...

# %%
newDStream = textDStream.transform(process)

# %%
newDStream.foreachRDD(process_query)

# %%
ssc.start()

# %% [markdown]
# ##### Stop Streaming

# %%
# ssc.stop(stopSparkContext=False,stopGraceFully=True)
# Out:
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Avery,White Easy Peel Return Address Labels                     |Twitter |1522067675777 |Visitor-525555|
# |add_to_cart|Page-12|        |Mrs. Meyer's Clean Day,"Liquid Hand Soap Refill, Lavender Scent"|Twitter |1522067676737 |Visitor-399542|
# |page_view  |Page-12|        |Honeywell,Power Air Circulator                                  |Other   |1522067676737 |Visitor-682688|
# |page_view  |Page-3 |        |Cloud 9,Cutlery Combo                                           |Google  |1522067677217 |Visitor-159375|
# |page_view  |Page-0 |        |Nintendo,Super Mario Galaxy                                     |Facebook|1522067677217 |Visitor-483425|
# |page_view  |Page-13|        |Kleenex,White Tissues                                           |Other   |1522067677217 |Visitor-375756|
# |page_view  |Page-3 |        |Spectrum Naturals,Peanut Oil                                    |Other   |1522067677217 |Visitor-861614|
# |page_view  |Page-4 |        |Trident,"16ct White Gum, Peppermint"                            |Google  |1522067677217 |Visitor-456684|
# |page_view  |Page-9 |        |Sharpie,Ultra Fine Permanent Marker                             |Other   |1522067677697 |Visitor-301112|
# |page_view  |Page-3 |        |Motorola,SURFboard eXtreme Cable Modem (Model SB6121)           |Yahoo   |1522067677697 |Visitor-315683|
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Avery,White Easy Peel Return Address Labels                     |Twitter |2018-03-26    |Visitor-525555|
# |add_to_cart|Page-12|        |Mrs. Meyer's Clean Day,"Liquid Hand Soap Refill, Lavender Scent"|Twitter |2018-03-26    |Visitor-399542|
# |page_view  |Page-12|        |Honeywell,Power Air Circulator                                  |Other   |2018-03-26    |Visitor-682688|
# |page_view  |Page-3 |        |Cloud 9,Cutlery Combo                                           |Google  |2018-03-26    |Visitor-159375|
# |page_view  |Page-0 |        |Nintendo,Super Mario Galaxy                                     |Facebook|2018-03-26    |Visitor-483425|
# |page_view  |Page-13|        |Kleenex,White Tissues                                           |Other   |2018-03-26    |Visitor-375756|
# |page_view  |Page-3 |        |Spectrum Naturals,Peanut Oil                                    |Other   |2018-03-26    |Visitor-861614|
# |page_view  |Page-4 |        |Trident,"16ct White Gum, Peppermint"                            |Google  |2018-03-26    |Visitor-456684|
# |page_view  |Page-9 |        |Sharpie,Ultra Fine Permanent Marker                             |Other   |2018-03-26    |Visitor-301112|
# |page_view  |Page-3 |        |Motorola,SURFboard eXtreme Cable Modem (Model SB6121)           |Yahoo   |2018-03-26    |Visitor-315683|
# +-----------+-------+--------+----------------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-12|Page-4  |Crest,Pro-Health Clean Mint Toothpaste                         |Internal|1522067686134 |Visitor-255911|
# |add_to_cart|Page-13|        |Coop,Tiefkühlbeutel mit Druckverschluss                        |Google  |1522067687094 |Visitor-435110|
# |page_view  |Page-8 |        |Kleenex,2-Ply White Tissues (208 × 213 mm/ 8.2 × 8.4 in)       |Other   |1522067687574 |Visitor-236743|
# |purchase   |Page-11|        |Clean & Clear,Essentials Foaming Facial Cleanser Sensitive Skin|Twitter |1522067688054 |Visitor-24223 |
# |page_view  |Page-4 |        |Trader Joe's,Sesame Melba Round Crackers                       |Google  |1522067688054 |Visitor-493187|
# |page_view  |Page-1 |        |Gillette,Arctic Ice Clear Gel Deodorant                        |Facebook|1522067688054 |Visitor-555630|
# |page_view  |Page-10|        |Omega,J8004 Nutrition Center Juicer                            |Facebook|1522067688054 |Visitor-950771|
# |page_view  |Page-2 |        |Walgreens,Advanced Hand Sanitizer with Aloe                    |Yahoo   |1522067688534 |Visitor-209991|
# |page_view  |Page-14|        |Scrub Daddy,Sponge Daddy                                       |Facebook|1522067688534 |Visitor-120174|
# |page_view  |Page-13|        |Sun Vista,Black Beans No Salt Added                            |Bing    |1522067688534 |Visitor-435049|
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-12|Page-4  |Crest,Pro-Health Clean Mint Toothpaste                         |Internal|2018-03-26    |Visitor-255911|
# |add_to_cart|Page-13|        |Coop,Tiefkühlbeutel mit Druckverschluss                        |Google  |2018-03-26    |Visitor-435110|
# |page_view  |Page-8 |        |Kleenex,2-Ply White Tissues (208 × 213 mm/ 8.2 × 8.4 in)       |Other   |2018-03-26    |Visitor-236743|
# |purchase   |Page-11|        |Clean & Clear,Essentials Foaming Facial Cleanser Sensitive Skin|Twitter |2018-03-26    |Visitor-24223 |
# |page_view  |Page-4 |        |Trader Joe's,Sesame Melba Round Crackers                       |Google  |2018-03-26    |Visitor-493187|
# |page_view  |Page-1 |        |Gillette,Arctic Ice Clear Gel Deodorant                        |Facebook|2018-03-26    |Visitor-555630|
# |page_view  |Page-10|        |Omega,J8004 Nutrition Center Juicer                            |Facebook|2018-03-26    |Visitor-950771|
# |page_view  |Page-2 |        |Walgreens,Advanced Hand Sanitizer with Aloe                    |Yahoo   |2018-03-26    |Visitor-209991|
# |page_view  |Page-14|        |Scrub Daddy,Sponge Daddy                                       |Facebook|2018-03-26    |Visitor-120174|
# |page_view  |Page-13|        |Sun Vista,Black Beans No Salt Added                            |Bing    |2018-03-26    |Visitor-435049|
# +-----------+-------+--------+---------------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Charmin,Ultra Soft                     |Google  |1522067688218 |Visitor-676807|
# |add_to_cart|Page-4 |        |Coop,Tiefkühlbeutel mit Druckverschluss|Google  |1522067688698 |Visitor-997945|
# |page_view  |Page-2 |        |All,"Mighty Pacs, Free Clear"          |Direct  |1522067688698 |Visitor-277908|
# |page_view  |Page-13|        |Safeway,Whole Black Pepper             |Bing    |1522067688698 |Visitor-44029 |
# |page_view  |Page-3 |        |Opti-Free,Pure Moist Contact Solution  |Facebook|1522067688698 |Visitor-158362|
# |page_view  |Page-12|        |e.l.f.,Eyebrow Kit- Darl               |Yahoo   |1522067688698 |Visitor-796491|
# |page_view  |Page-1 |        |Google,Chromecast                      |Google  |1522067689178 |Visitor-367921|
# |page_view  |Page-14|        |CVS,2-Ply Tissues                      |Yahoo   |1522067689178 |Visitor-505258|
# |page_view  |Page-11|        |Mars,Peanut M&M                        |Google  |1522067689178 |Visitor-379920|
# |page_view  |Page-11|        |Arm & Hammer,Ultra Max Deodorant       |Bing    |1522067689178 |Visitor-42678 |
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# |purchase   |Page-7 |        |Charmin,Ultra Soft                     |Google  |2018-03-26    |Visitor-676807|
# |add_to_cart|Page-4 |        |Coop,Tiefkühlbeutel mit Druckverschluss|Google  |2018-03-26    |Visitor-997945|
# |page_view  |Page-2 |        |All,"Mighty Pacs, Free Clear"          |Direct  |2018-03-26    |Visitor-277908|
# |page_view  |Page-13|        |Safeway,Whole Black Pepper             |Bing    |2018-03-26    |Visitor-44029 |
# |page_view  |Page-3 |        |Opti-Free,Pure Moist Contact Solution  |Facebook|2018-03-26    |Visitor-158362|
# |page_view  |Page-12|        |e.l.f.,Eyebrow Kit- Darl               |Yahoo   |2018-03-26    |Visitor-796491|
# |page_view  |Page-1 |        |Google,Chromecast                      |Google  |2018-03-26    |Visitor-367921|
# |page_view  |Page-14|        |CVS,2-Ply Tissues                      |Yahoo   |2018-03-26    |Visitor-505258|
# |page_view  |Page-11|        |Mars,Peanut M&M                        |Google  |2018-03-26    |Visitor-379920|
# |page_view  |Page-11|        |Arm & Hammer,Ultra Max Deodorant       |Bing    |2018-03-26    |Visitor-42678 |
# +-----------+-------+--------+---------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|        |Palmolive,Original Dish Liquid                |Bing    |1522067690284 |Visitor-4928  |
# |add_to_cart|Page-13|        |The Body Shop,Coconut Body Butter             |Google  |1522067690764 |Visitor-517592|
# |page_view  |Page-4 |        |CeraVe,Facial Moisturizing Lotion             |Google  |1522067690764 |Visitor-338234|
# |page_view  |Page-8 |        |Energizer,392 Watch Battery                   |Direct  |1522067690764 |Visitor-787703|
# |page_view  |Page-14|        |Pond's,Dry Skin Cream                         |Bing    |1522067690764 |Visitor-262273|
# |page_view  |Page-8 |        |Crest,Pro-Health Fluoride Rinse               |Other   |1522067691244 |Visitor-726400|
# |page_view  |Page-5 |        |Arduino,Yun                                   |Other   |1522067691244 |Visitor-586672|
# |page_view  |Page-12|        |Ralphs,Nice 'n Elegant Spoons                 |Bing    |1522067691244 |Visitor-44838 |
# |page_view  |Page-10|        |Elmer's,Disappearing Purple School Glue Sticks|Yahoo   |1522067691244 |Visitor-162726|
# |page_view  |Page-10|        |HDX,Table Top Air Circulator                  |Bing    |1522067691244 |Visitor-671826|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|        |Palmolive,Original Dish Liquid                |Bing    |2018-03-26    |Visitor-4928  |
# |add_to_cart|Page-13|        |The Body Shop,Coconut Body Butter             |Google  |2018-03-26    |Visitor-517592|
# |page_view  |Page-4 |        |CeraVe,Facial Moisturizing Lotion             |Google  |2018-03-26    |Visitor-338234|
# |page_view  |Page-8 |        |Energizer,392 Watch Battery                   |Direct  |2018-03-26    |Visitor-787703|
# |page_view  |Page-14|        |Pond's,Dry Skin Cream                         |Bing    |2018-03-26    |Visitor-262273|
# |page_view  |Page-8 |        |Crest,Pro-Health Fluoride Rinse               |Other   |2018-03-26    |Visitor-726400|
# |page_view  |Page-5 |        |Arduino,Yun                                   |Other   |2018-03-26    |Visitor-586672|
# |page_view  |Page-12|        |Ralphs,Nice 'n Elegant Spoons                 |Bing    |2018-03-26    |Visitor-44838 |
# |page_view  |Page-10|        |Elmer's,Disappearing Purple School Glue Sticks|Yahoo   |2018-03-26    |Visitor-162726|
# |page_view  |Page-10|        |HDX,Table Top Air Circulator                  |Bing    |2018-03-26    |Visitor-671826|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|Page-5  |Charmin,Ultra Soft                                      |Internal|1522067692335 |Visitor-477110|
# |add_to_cart|Page-1 |        |Comet,Comet With Bleach                                 |Other   |1522067692815 |Visitor-318236|
# |page_view  |Page-1 |        |Sol Republic,JAX Headphones                             |Twitter |1522067692815 |Visitor-512775|
# |page_view  |Page-5 |        |CVS,2-Ply Tissues                                       |Other   |1522067692815 |Visitor-914876|
# |page_view  |Page-10|        |Banana Boat,Sport Performance- UVA/UVB protection SPF 30|Direct  |1522067692815 |Visitor-205288|
# |page_view  |Page-8 |        |Lysol,Bathroom Cleaner with Hydrogen Peroxide           |Yahoo   |1522067692815 |Visitor-880433|
# |page_view  |Page-13|        |Trader Joe's,Curry Powder                               |Other   |1522067693295 |Visitor-475210|
# |page_view  |Page-10|        |Clif Bar,Chocolate Almond Fudge Energy Bar              |Yahoo   |1522067693295 |Visitor-242016|
# |page_view  |Page-7 |        |Staples,Standard Staples                                |Direct  |1522067693295 |Visitor-71790 |
# |page_view  |Page-5 |        |Caliber,Security Envelopes                              |Yahoo   |1522067693295 |Visitor-294705|
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-11|Page-5  |Charmin,Ultra Soft                                      |Internal|2018-03-26    |Visitor-477110|
# |add_to_cart|Page-1 |        |Comet,Comet With Bleach                                 |Other   |2018-03-26    |Visitor-318236|
# |page_view  |Page-1 |        |Sol Republic,JAX Headphones                             |Twitter |2018-03-26    |Visitor-512775|
# |page_view  |Page-5 |        |CVS,2-Ply Tissues                                       |Other   |2018-03-26    |Visitor-914876|
# |page_view  |Page-10|        |Banana Boat,Sport Performance- UVA/UVB protection SPF 30|Direct  |2018-03-26    |Visitor-205288|
# |page_view  |Page-8 |        |Lysol,Bathroom Cleaner with Hydrogen Peroxide           |Yahoo   |2018-03-26    |Visitor-880433|
# |page_view  |Page-13|        |Trader Joe's,Curry Powder                               |Other   |2018-03-26    |Visitor-475210|
# |page_view  |Page-10|        |Clif Bar,Chocolate Almond Fudge Energy Bar              |Yahoo   |2018-03-26    |Visitor-242016|
# |page_view  |Page-7 |        |Staples,Standard Staples                                |Direct  |2018-03-26    |Visitor-71790 |
# |page_view  |Page-5 |        |Caliber,Security Envelopes                              |Yahoo   |2018-03-26    |Visitor-294705|
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# |purchase   |Page-4 |        |David's Tea,Birthday Cake        |Yahoo   |1522067694409 |Visitor-227662|
# |add_to_cart|Page-6 |        |Avery,White Reinforcement Labels |Bing    |1522067694889 |Visitor-546744|
# |page_view  |Page-5 |        |Orbit,Spearmint Sugarfree Gum    |Direct  |1522067694889 |Visitor-457686|
# |page_view  |Page-5 |        |Biotene,Dry Mouth  Oral Rinse    |Bing    |1522067694889 |Visitor-731981|
# |page_view  |Page-13|        |Gatorade,Frost Riptide Rush      |Yahoo   |1522067694889 |Visitor-569633|
# |page_view  |Page-4 |        |Fernet-Branca,Liqueur            |Yahoo   |1522067694889 |Visitor-729034|
# |page_view  |Page-11|        |SteamFast,Travel Steam Iron      |Google  |1522067694889 |Visitor-584654|
# |page_view  |Page-3 |        |Scrub Daddy,Sponge Daddy         |Other   |1522067694889 |Visitor-500286|
# |page_view  |Page-12|        |Trader Joe's,Curry Powder        |Twitter |1522067694889 |Visitor-191599|
# |page_view  |Page-4 |        |Sensodyne,Fresh Impact Toothpaste|Yahoo   |1522067694889 |Visitor-251920|
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# |purchase   |Page-4 |        |David's Tea,Birthday Cake        |Yahoo   |2018-03-26    |Visitor-227662|
# |add_to_cart|Page-6 |        |Avery,White Reinforcement Labels |Bing    |2018-03-26    |Visitor-546744|
# |page_view  |Page-5 |        |Orbit,Spearmint Sugarfree Gum    |Direct  |2018-03-26    |Visitor-457686|
# |page_view  |Page-5 |        |Biotene,Dry Mouth  Oral Rinse    |Bing    |2018-03-26    |Visitor-731981|
# |page_view  |Page-13|        |Gatorade,Frost Riptide Rush      |Yahoo   |2018-03-26    |Visitor-569633|
# |page_view  |Page-4 |        |Fernet-Branca,Liqueur            |Yahoo   |2018-03-26    |Visitor-729034|
# |page_view  |Page-11|        |SteamFast,Travel Steam Iron      |Google  |2018-03-26    |Visitor-584654|
# |page_view  |Page-3 |        |Scrub Daddy,Sponge Daddy         |Other   |2018-03-26    |Visitor-500286|
# |page_view  |Page-12|        |Trader Joe's,Curry Powder        |Twitter |2018-03-26    |Visitor-191599|
# |page_view  |Page-4 |        |Sensodyne,Fresh Impact Toothpaste|Yahoo   |2018-03-26    |Visitor-251920|
# +-----------+-------+--------+---------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                   |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-8 |        |e.l.f.,Eyebrow Kit- Darl                  |Google  |1522067696470 |Visitor-630776|
# |add_to_cart|Page-5 |        |Nature Made,D3 400 IU                     |Google  |1522067696470 |Visitor-736482|
# |page_view  |Page-12|        |Q-tips,Cotton Swabs                       |Bing    |1522067696470 |Visitor-313458|
# |page_view  |Page-5 |        |Gatorade,Frost Riptide Rush               |Facebook|1522067696470 |Visitor-71054 |
# |page_view  |Page-4 |        |Cen-Tech,7 Function Digital Multimeter    |Twitter |1522067696950 |Visitor-18998 |
# |page_view  |Page-5 |Page-4  |CVS Total Home,"Aluminum Foil, Heavy Duty"|Internal|1522067696950 |Visitor-38783 |
# |page_view  |Page-6 |        |Colgate,Toothbrush Value Pack             |Facebook|1522067696950 |Visitor-446182|
# |page_view  |Page-8 |        |Google,Chromecast                         |Twitter |1522067696950 |Visitor-716027|
# |page_view  |Page-8 |        |Gatorade,Perform Fruit Punch              |Facebook|1522067696950 |Visitor-538631|
# |page_view  |Page-4 |Page-7  |Kroger,Granulated Sugar                   |Internal|1522067696950 |Visitor-431430|
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                   |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-8 |        |e.l.f.,Eyebrow Kit- Darl                  |Google  |2018-03-26    |Visitor-630776|
# |add_to_cart|Page-5 |        |Nature Made,D3 400 IU                     |Google  |2018-03-26    |Visitor-736482|
# |page_view  |Page-12|        |Q-tips,Cotton Swabs                       |Bing    |2018-03-26    |Visitor-313458|
# |page_view  |Page-5 |        |Gatorade,Frost Riptide Rush               |Facebook|2018-03-26    |Visitor-71054 |
# |page_view  |Page-4 |        |Cen-Tech,7 Function Digital Multimeter    |Twitter |2018-03-26    |Visitor-18998 |
# |page_view  |Page-5 |Page-4  |CVS Total Home,"Aluminum Foil, Heavy Duty"|Internal|2018-03-26    |Visitor-38783 |
# |page_view  |Page-6 |        |Colgate,Toothbrush Value Pack             |Facebook|2018-03-26    |Visitor-446182|
# |page_view  |Page-8 |        |Google,Chromecast                         |Twitter |2018-03-26    |Visitor-716027|
# |page_view  |Page-8 |        |Gatorade,Perform Fruit Punch              |Facebook|2018-03-26    |Visitor-538631|
# |page_view  |Page-4 |Page-7  |Kroger,Granulated Sugar                   |Internal|2018-03-26    |Visitor-431430|
# +-----------+-------+--------+------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|        |Kroger,Vanilla Extract                        |Other   |1522067698528 |Visitor-892823|
# |add_to_cart|Page-5 |Page-8  |Palmolive,Original Dish Liquid                |Internal|1522067699008 |Visitor-389881|
# |page_view  |Page-11|        |l'Oreal,EverStrong Hydrate Conditioner        |Twitter |1522067699008 |Visitor-253713|
# |page_view  |Page-6 |        |Kroger,Garlic Salt                            |Bing    |1522067699008 |Visitor-336049|
# |page_view  |Page-1 |        |Gillette,Arctic Ice Clear Gel Deodorant       |Other   |1522067699008 |Visitor-628367|
# |page_view  |Page-4 |        |Mars,Peanut M&M                               |Google  |1522067699488 |Visitor-502342|
# |page_view  |Page-9 |        |Avery,White Reinforcement Labels              |Other   |1522067699488 |Visitor-13939 |
# |page_view  |Page-10|        |California Pizza Kitchen,Sicilian Recipe Pizza|Yahoo   |1522067699488 |Visitor-910540|
# |page_view  |Page-6 |        |Gunnar,Vayper Onyx Advanced Gaming Eyewear    |Google  |1522067699488 |Visitor-97441 |
# |page_view  |Page-12|Page-5  |Reynolds,Wrap                                 |Internal|1522067699968 |Visitor-908989|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|        |Kroger,Vanilla Extract                        |Other   |2018-03-26    |Visitor-892823|
# |add_to_cart|Page-5 |Page-8  |Palmolive,Original Dish Liquid                |Internal|2018-03-26    |Visitor-389881|
# |page_view  |Page-11|        |l'Oreal,EverStrong Hydrate Conditioner        |Twitter |2018-03-26    |Visitor-253713|
# |page_view  |Page-6 |        |Kroger,Garlic Salt                            |Bing    |2018-03-26    |Visitor-336049|
# |page_view  |Page-1 |        |Gillette,Arctic Ice Clear Gel Deodorant       |Other   |2018-03-26    |Visitor-628367|
# |page_view  |Page-4 |        |Mars,Peanut M&M                               |Google  |2018-03-26    |Visitor-502342|
# |page_view  |Page-9 |        |Avery,White Reinforcement Labels              |Other   |2018-03-26    |Visitor-13939 |
# |page_view  |Page-10|        |California Pizza Kitchen,Sicilian Recipe Pizza|Yahoo   |2018-03-26    |Visitor-910540|
# |page_view  |Page-6 |        |Gunnar,Vayper Onyx Advanced Gaming Eyewear    |Google  |2018-03-26    |Visitor-97441 |
# |page_view  |Page-12|Page-5  |Reynolds,Wrap                                 |Internal|2018-03-26    |Visitor-908989|
# +-----------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6 |        |Dixie,Paper Plates                              |Bing    |1522067700628 |Visitor-614681|
# |add_to_cart|Page-11|        |Santa Sweets,Grape Tomatoes                     |Other   |1522067701588 |Visitor-811814|
# |page_view  |Page-14|Page-12 |Tapatio,Salsa Picante                           |Internal|1522067701588 |Visitor-948542|
# |page_view  |Page-9 |        |Sanyo,Eneloop 4 AA Batteries and Charger        |Bing    |1522067701588 |Visitor-588605|
# |page_view  |Page-5 |        |CVS Pharmacy,200mg Ibuprofen Capsules           |Facebook|1522067701588 |Visitor-614885|
# |page_view  |Page-13|        |CVS,2-Ply Tissues                               |Direct  |1522067701588 |Visitor-469653|
# |purchase   |Page-13|        |Scott,One Ply Bathroom Tissue                   |Google  |1522067702068 |Visitor-338485|
# |page_view  |Page-6 |        |Gatorade,Perform Fruit Punch                    |Other   |1522067702068 |Visitor-517214|
# |page_view  |Page-5 |        |Natural Grooming by Herban Cowboy,Dusk Deodorant|Direct  |1522067702068 |Visitor-283478|
# |page_view  |Page-11|        |Lancome,Creme Radiance                          |Yahoo   |1522067702548 |Visitor-639523|
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                         |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-6 |        |Dixie,Paper Plates                              |Bing    |2018-03-26    |Visitor-614681|
# |add_to_cart|Page-11|        |Santa Sweets,Grape Tomatoes                     |Other   |2018-03-26    |Visitor-811814|
# |page_view  |Page-14|Page-12 |Tapatio,Salsa Picante                           |Internal|2018-03-26    |Visitor-948542|
# |page_view  |Page-9 |        |Sanyo,Eneloop 4 AA Batteries and Charger        |Bing    |2018-03-26    |Visitor-588605|
# |page_view  |Page-5 |        |CVS Pharmacy,200mg Ibuprofen Capsules           |Facebook|2018-03-26    |Visitor-614885|
# |page_view  |Page-13|        |CVS,2-Ply Tissues                               |Direct  |2018-03-26    |Visitor-469653|
# |purchase   |Page-13|        |Scott,One Ply Bathroom Tissue                   |Google  |2018-03-26    |Visitor-338485|
# |page_view  |Page-6 |        |Gatorade,Perform Fruit Punch                    |Other   |2018-03-26    |Visitor-517214|
# |page_view  |Page-5 |        |Natural Grooming by Herban Cowboy,Dusk Deodorant|Direct  |2018-03-26    |Visitor-283478|
# |page_view  |Page-11|        |Lancome,Creme Radiance                          |Yahoo   |2018-03-26    |Visitor-639523|
# +-----------+-------+--------+------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                    |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|Page-7  |Annie's,Shells & Real Aged Cheddar Macaroni & Cheese       |Internal|1522067702686 |Visitor-323938|
# |add_to_cart|Page-11|Page-4  |Crest,Pro-Health Clean Mint Toothpaste                     |Internal|1522067703166 |Visitor-145154|
# |page_view  |Page-7 |        |Santa Sweets,Grape Tomatoes                                |Direct  |1522067703166 |Visitor-342720|
# |page_view  |Page-7 |Page-4  |The Learning Company,Where in the U.S.A. is Carmen Sandiego|Internal|1522067703166 |Visitor-731452|
# |page_view  |Page-9 |        |Heinz,Tomato Ketchup                                       |Bing    |1522067703166 |Visitor-839226|
# |page_view  |Page-13|Page-12 |David's Tea,Bubbie's Baklava Oolong Tea                    |Internal|1522067703166 |Visitor-402357|
# |page_view  |Page-4 |        |Air Wick,Dual Action Spray                                 |Facebook|1522067703646 |Visitor-702979|
# |page_view  |Page-1 |        |Tropicana,Orange Juice with Calcium & Vitamin D            |Direct  |1522067703646 |Visitor-621504|
# |page_view  |Page-14|        |Nature Made,D3 400 IU                                      |Twitter |1522067703646 |Visitor-953298|
# |page_view  |Page-1 |        |Air Wick,Dual Action Spray                                 |Twitter |1522067703646 |Visitor-866203|
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                                    |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-10|Page-7  |Annie's,Shells & Real Aged Cheddar Macaroni & Cheese       |Internal|2018-03-26    |Visitor-323938|
# |add_to_cart|Page-11|Page-4  |Crest,Pro-Health Clean Mint Toothpaste                     |Internal|2018-03-26    |Visitor-145154|
# |page_view  |Page-7 |        |Santa Sweets,Grape Tomatoes                                |Direct  |2018-03-26    |Visitor-342720|
# |page_view  |Page-7 |Page-4  |The Learning Company,Where in the U.S.A. is Carmen Sandiego|Internal|2018-03-26    |Visitor-731452|
# |page_view  |Page-9 |        |Heinz,Tomato Ketchup                                       |Bing    |2018-03-26    |Visitor-839226|
# |page_view  |Page-13|Page-12 |David's Tea,Bubbie's Baklava Oolong Tea                    |Internal|2018-03-26    |Visitor-402357|
# |page_view  |Page-4 |        |Air Wick,Dual Action Spray                                 |Facebook|2018-03-26    |Visitor-702979|
# |page_view  |Page-1 |        |Tropicana,Orange Juice with Calcium & Vitamin D            |Direct  |2018-03-26    |Visitor-621504|
# |page_view  |Page-14|        |Nature Made,D3 400 IU                                      |Twitter |2018-03-26    |Visitor-953298|
# |page_view  |Page-1 |        |Air Wick,Dual Action Spray                                 |Twitter |2018-03-26    |Visitor-866203|
# +-----------+-------+--------+-----------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# |purchase   |Page-5 |        |RadioShack,PIR Sensor                   |Bing    |1522067704734 |Visitor-618612|
# |add_to_cart|Page-6 |        |CeraVe,Facial Moisturizing Lotion       |Other   |1522067704734 |Visitor-101312|
# |page_view  |Page-8 |        |Secret,pH Balanced - Unscented          |Direct  |1522067704734 |Visitor-582631|
# |page_view  |Page-11|        |e.l.f.,Matte Lip Color-Paline           |Google  |1522067704734 |Visitor-892835|
# |page_view  |Page-14|        |Aveeno,Men's After Shave Lotion         |Yahoo   |1522067704734 |Visitor-718201|
# |page_view  |Page-5 |        |Rosewill,Hard Drive Docking             |Yahoo   |1522067704734 |Visitor-731443|
# |page_view  |Page-7 |        |Mars,Peanut Butter M&M Chocolate Candies|Yahoo   |1522067704734 |Visitor-780984|
# |page_view  |Page-10|Page-2  |Glass Plus,Glass Cleaner                |Internal|1522067704734 |Visitor-815289|
# |page_view  |Page-12|Page-2  |Gillette,Arctic Ice Clear Gel Deodorant |Internal|1522067705214 |Visitor-786739|
# |page_view  |Page-13|Page-11 |Palmolive,Original Dish Liquid          |Internal|1522067705214 |Visitor-75213 |
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                 |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# |purchase   |Page-5 |        |RadioShack,PIR Sensor                   |Bing    |2018-03-26    |Visitor-618612|
# |add_to_cart|Page-6 |        |CeraVe,Facial Moisturizing Lotion       |Other   |2018-03-26    |Visitor-101312|
# |page_view  |Page-8 |        |Secret,pH Balanced - Unscented          |Direct  |2018-03-26    |Visitor-582631|
# |page_view  |Page-11|        |e.l.f.,Matte Lip Color-Paline           |Google  |2018-03-26    |Visitor-892835|
# |page_view  |Page-14|        |Aveeno,Men's After Shave Lotion         |Yahoo   |2018-03-26    |Visitor-718201|
# |page_view  |Page-5 |        |Rosewill,Hard Drive Docking             |Yahoo   |2018-03-26    |Visitor-731443|
# |page_view  |Page-7 |        |Mars,Peanut Butter M&M Chocolate Candies|Yahoo   |2018-03-26    |Visitor-780984|
# |page_view  |Page-10|Page-2  |Glass Plus,Glass Cleaner                |Internal|2018-03-26    |Visitor-815289|
# |page_view  |Page-12|Page-2  |Gillette,Arctic Ice Clear Gel Deodorant |Internal|2018-03-26    |Visitor-786739|
# |page_view  |Page-13|Page-11 |Palmolive,Original Dish Liquid          |Internal|2018-03-26    |Visitor-75213 |
# +-----------+-------+--------+----------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                    |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |purchase |Page-14|        |e.l.f.,Matte Lip Color-Paline              |Facebook|1522067706784 |Visitor-790768|
# |page_view|Page-6 |        |Chobani,Greek Yogurt - Plain               |Other   |1522067706784 |Visitor-494202|
# |page_view|Page-2 |        |Dust Destroyer,Compressed-Gas Duster       |Twitter |1522067706784 |Visitor-853532|
# |page_view|Page-5 |        |Jergens,Natural Glow                       |Yahoo   |1522067707264 |Visitor-433739|
# |page_view|Page-3 |        |e.l.f.,Jumbo Eyeshadow Stick-Turkish Coffee|Google  |1522067707264 |Visitor-81655 |
# |page_view|Page-11|        |Gunnar,Vayper Onyx Advanced Gaming Eyewear |Google  |1522067707264 |Visitor-669410|
# |page_view|Page-7 |Page-6  |Meijer,Vitamin C 500 mg                    |Internal|1522067707264 |Visitor-93161 |
# |page_view|Page-8 |        |Trader Joe's,Curry Powder                  |Direct  |1522067707264 |Visitor-911767|
# |page_view|Page-11|        |Purity Farms,Organic Ghee                  |Direct  |1522067707264 |Visitor-779606|
# |page_view|Page-13|Page-13 |Glade,Clean Linen Air Freshener            |Internal|1522067707264 |Visitor-962096|
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                    |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |purchase |Page-14|        |e.l.f.,Matte Lip Color-Paline              |Facebook|2018-03-26    |Visitor-790768|
# |page_view|Page-6 |        |Chobani,Greek Yogurt - Plain               |Other   |2018-03-26    |Visitor-494202|
# |page_view|Page-2 |        |Dust Destroyer,Compressed-Gas Duster       |Twitter |2018-03-26    |Visitor-853532|
# |page_view|Page-5 |        |Jergens,Natural Glow                       |Yahoo   |2018-03-26    |Visitor-433739|
# |page_view|Page-3 |        |e.l.f.,Jumbo Eyeshadow Stick-Turkish Coffee|Google  |2018-03-26    |Visitor-81655 |
# |page_view|Page-11|        |Gunnar,Vayper Onyx Advanced Gaming Eyewear |Google  |2018-03-26    |Visitor-669410|
# |page_view|Page-7 |Page-6  |Meijer,Vitamin C 500 mg                    |Internal|2018-03-26    |Visitor-93161 |
# |page_view|Page-8 |        |Trader Joe's,Curry Powder                  |Direct  |2018-03-26    |Visitor-911767|
# |page_view|Page-11|        |Purity Farms,Organic Ghee                  |Direct  |2018-03-26    |Visitor-779606|
# |page_view|Page-13|Page-13 |Glade,Clean Linen Air Freshener            |Internal|2018-03-26    |Visitor-962096|
# +---------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page  |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0|        |Orbit,Spearmint Sugarfree Gum                 |Yahoo   |1522067708844 |Visitor-657611|
# |add_to_cart|Page-4|        |Dixie,Paper Plates                            |Facebook|1522067709324 |Visitor-753760|
# |page_view  |Page-2|Page-11 |l'Oreal,EverStrong Hydrate Shampoo            |Internal|1522067709324 |Visitor-685650|
# |page_view  |Page-4|        |Kleenex,White Tissues                         |Google  |1522067709804 |Visitor-575713|
# |page_view  |Page-6|        |Opti-Free,Pure Moist Contact Solution         |Twitter |1522067709804 |Visitor-661719|
# |page_view  |Page-0|        |up & up,Toothbrush Holder                     |Direct  |1522067709804 |Visitor-50711 |
# |page_view  |Page-5|        |Menscience,Advanced Deodorant                 |Other   |1522067709804 |Visitor-365534|
# |page_view  |Page-8|        |Safeway,Blue Mint Antiseptic Mouth Rinse      |Other   |1522067709804 |Visitor-499303|
# |page_view  |Page-4|Page-2  |Trident,"White Gum, Peppermint"               |Internal|1522067710284 |Visitor-759570|
# |page_view  |Page-5|Page-4  |Elmer's,Disappearing Purple School Glue Sticks|Internal|1522067710284 |Visitor-730021|
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# |action     |page  |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-0|        |Orbit,Spearmint Sugarfree Gum                 |Yahoo   |2018-03-26    |Visitor-657611|
# |add_to_cart|Page-4|        |Dixie,Paper Plates                            |Facebook|2018-03-26    |Visitor-753760|
# |page_view  |Page-2|Page-11 |l'Oreal,EverStrong Hydrate Shampoo            |Internal|2018-03-26    |Visitor-685650|
# |page_view  |Page-4|        |Kleenex,White Tissues                         |Google  |2018-03-26    |Visitor-575713|
# |page_view  |Page-6|        |Opti-Free,Pure Moist Contact Solution         |Twitter |2018-03-26    |Visitor-661719|
# |page_view  |Page-0|        |up & up,Toothbrush Holder                     |Direct  |2018-03-26    |Visitor-50711 |
# |page_view  |Page-5|        |Menscience,Advanced Deodorant                 |Other   |2018-03-26    |Visitor-365534|
# |page_view  |Page-8|        |Safeway,Blue Mint Antiseptic Mouth Rinse      |Other   |2018-03-26    |Visitor-499303|
# |page_view  |Page-4|Page-2  |Trident,"White Gum, Peppermint"               |Internal|2018-03-26    |Visitor-759570|
# |page_view  |Page-5|Page-4  |Elmer's,Disappearing Purple School Glue Sticks|Internal|2018-03-26    |Visitor-730021|
# +-----------+------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
# ...
# |purchase   |Page-7 |        |Purity Farms,Organic Ghee                               |Google  |2018-03-26    |Visitor-898943|
# |add_to_cart|Page-5 |        |Elmer's,Disappearing Purple School Glue Sticks          |Yahoo   |2018-03-26    |Visitor-967654|
# |page_view  |Page-14|        |Tide,Febreze Fresh Laundry Detergent                    |Twitter |2018-03-26    |Visitor-169433|
# |page_view  |Page-10|        |Kleenex,2-Ply White Tissues (208 × 213 mm/ 8.2 × 8.4 in)|Twitter |2018-03-26    |Visitor-79558 |
# |page_view  |Page-8 |        |Fernet-Branca,Liqueur                                   |Bing    |2018-03-26    |Visitor-867609|
# |page_view  |Page-3 |        |Jolen,Creme Bleach - Lightens Excess Dark Hair          |Bing    |2018-03-26    |Visitor-128175|
# |page_view  |Page-6 |        |Trader Joe's,Sesame Melba Round Crackers                |Direct  |2018-03-26    |Visitor-138877|
# |page_view  |Page-4 |        |So Delicious,Coconut Milk                               |Google  |2018-03-26    |Visitor-887453|
# |page_view  |Page-7 |        |Walgreens,Advanced Hand Sanitizer with Aloe             |Yahoo   |2018-03-26    |Visitor-164769|
# |page_view  |Page-14|Page-5  |Sharpie,Fine Permanent Marker                           |Internal|2018-03-26    |Visitor-194441|
# +-----------+-------+--------+--------------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-9 |Page-1  |Charmin,Ultra Soft                             |Internal|1522067743766 |Visitor-886612|
# |add_to_cart|Page-12|        |aussie,Instant Freeze Gel                      |Twitter |1522067744246 |Visitor-660641|
# |page_view  |Page-10|        |Crest,Pro-Health Fluoride Rinse                |Yahoo   |1522067745206 |Visitor-574738|
# |page_view  |Page-10|        |Reynolds,Parchment Paper                       |Other   |1522067745686 |Visitor-367467|
# |page_view  |Page-5 |        |Aveeno,Clear Complexion Foaming Cleanser       |Other   |1522067746166 |Visitor-578136|
# |page_view  |Page-13|        |Expo,Dry Erase Markers                         |Direct  |1522067746166 |Visitor-712740|
# |page_view  |Page-13|        |Wholesome Kitchen,Farro and Garden Vegetable   |Yahoo   |1522067746166 |Visitor-245474|
# |page_view  |Page-11|        |Kind,Dark Chocolate Nuts & Sea Salt Protein Bar|Bing    |1522067746166 |Visitor-768045|
# |page_view  |Page-5 |        |Kroger,Garlic Salt                             |Bing    |1522067746166 |Visitor-411854|
# |page_view  |Page-0 |Page-12 |McCormick,Pure Ground Black Pepper             |Internal|1522067746646 |Visitor-916384|
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                        |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-9 |Page-1  |Charmin,Ultra Soft                             |Internal|2018-03-26    |Visitor-886612|
# |add_to_cart|Page-12|        |aussie,Instant Freeze Gel                      |Twitter |2018-03-26    |Visitor-660641|
# |page_view  |Page-10|        |Crest,Pro-Health Fluoride Rinse                |Yahoo   |2018-03-26    |Visitor-574738|
# |page_view  |Page-10|        |Reynolds,Parchment Paper                       |Other   |2018-03-26    |Visitor-367467|
# |page_view  |Page-5 |        |Aveeno,Clear Complexion Foaming Cleanser       |Other   |2018-03-26    |Visitor-578136|
# |page_view  |Page-13|        |Expo,Dry Erase Markers                         |Direct  |2018-03-26    |Visitor-712740|
# |page_view  |Page-13|        |Wholesome Kitchen,Farro and Garden Vegetable   |Yahoo   |2018-03-26    |Visitor-245474|
# |page_view  |Page-11|        |Kind,Dark Chocolate Nuts & Sea Salt Protein Bar|Bing    |2018-03-26    |Visitor-768045|
# |page_view  |Page-5 |        |Kroger,Garlic Salt                             |Bing    |2018-03-26    |Visitor-411854|
# |page_view  |Page-0 |Page-12 |McCormick,Pure Ground Black Pepper             |Internal|2018-03-26    |Visitor-916384|
# +-----------+-------+--------+-----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |page_view|Page-0 |        |Omega,J8004 Nutrition Center Juicer           |Direct  |1522067759126 |Visitor-927096|
# |page_view|Page-0 |        |Coca Cola,Soda                                |Yahoo   |1522067759126 |Visitor-393324|
# |page_view|Page-3 |        |Clif Bar,Berry Pomegranate Chia Energy Bar    |Twitter |1522067759126 |Visitor-176182|
# |page_view|Page-6 |        |Opti-Free,Pure Moist Contact Solution         |Google  |1522067759126 |Visitor-925733|
# |page_view|Page-13|        |Pentel,Super Hi-Polymer Lead 0.7              |Facebook|1522067759606 |Visitor-527729|
# |page_view|Page-11|        |Scrabble,Crossword Game                       |Facebook|1522067759606 |Visitor-79960 |
# |page_view|Page-5 |        |Avery,White Easy Peel Return Address Labels   |Yahoo   |1522067759606 |Visitor-82513 |
# |page_view|Page-11|        |Botanics,Hydrating Day Cream All Bright SPF 15|Direct  |1522067759606 |Visitor-100656|
# |page_view|Page-10|        |OYO,Whiskey                                   |Facebook|1522067759606 |Visitor-627955|
# |page_view|Page-7 |        |Reynolds,Parchment Paper                      |Yahoo   |1522067759606 |Visitor-961927|
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |action   |page   |prevPage|product                                       |referrer|timestamp_hour|visitor       |
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# |page_view|Page-0 |        |Omega,J8004 Nutrition Center Juicer           |Direct  |2018-03-26    |Visitor-927096|
# |page_view|Page-0 |        |Coca Cola,Soda                                |Yahoo   |2018-03-26    |Visitor-393324|
# |page_view|Page-3 |        |Clif Bar,Berry Pomegranate Chia Energy Bar    |Twitter |2018-03-26    |Visitor-176182|
# |page_view|Page-6 |        |Opti-Free,Pure Moist Contact Solution         |Google  |2018-03-26    |Visitor-925733|
# |page_view|Page-13|        |Pentel,Super Hi-Polymer Lead 0.7              |Facebook|2018-03-26    |Visitor-527729|
# |page_view|Page-11|        |Scrabble,Crossword Game                       |Facebook|2018-03-26    |Visitor-79960 |
# |page_view|Page-5 |        |Avery,White Easy Peel Return Address Labels   |Yahoo   |2018-03-26    |Visitor-82513 |
# |page_view|Page-11|        |Botanics,Hydrating Day Cream All Bright SPF 15|Direct  |2018-03-26    |Visitor-100656|
# |page_view|Page-10|        |OYO,Whiskey                                   |Facebook|2018-03-26    |Visitor-627955|
# |page_view|Page-7 |        |Reynolds,Parchment Paper                      |Yahoo   |2018-03-26    |Visitor-961927|
# +---------+-------+--------+----------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-4 |        |Colgate,Toothbrush Value Pack                    |Twitter |1522067745821 |Visitor-609615|
# |add_to_cart|Page-4 |        |Botanics,Hydrating Day Cream All Bright SPF 15   |Twitter |1522067747261 |Visitor-941462|
# |page_view  |Page-0 |        |SteamFast,Travel Steam Iron                      |Bing    |1522067747261 |Visitor-15346 |
# |page_view  |Page-0 |        |Annie's,Rice Pasta and Extra Cheesy Cheddar Sauce|Direct  |1522067747741 |Visitor-86200 |
# |page_view  |Page-12|        |aussie,Instant Freeze Gel                        |Other   |1522067747741 |Visitor-516444|
# |page_view  |Page-1 |        |Clorox,Disinfecting Wipes                        |Google  |1522067747741 |Visitor-697158|
# |page_view  |Page-6 |        |Scotch,Super 33+ Vinyl Electric Tape             |Direct  |1522067747741 |Visitor-432121|
# |page_view  |Page-7 |        |Trident,"16ct White Gum, Peppermint"             |Yahoo   |1522067748221 |Visitor-284260|
# |page_view  |Page-9 |Page-11 |Penn,Extra Duty Felt Tennis Ball                 |Internal|1522067748221 |Visitor-592081|
# |page_view  |Page-12|Page-5  |Clorox,Disinfecting Wipes                        |Internal|1522067748221 |Visitor-113728|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                          |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-4 |        |Colgate,Toothbrush Value Pack                    |Twitter |2018-03-26    |Visitor-609615|
# |add_to_cart|Page-4 |        |Botanics,Hydrating Day Cream All Bright SPF 15   |Twitter |2018-03-26    |Visitor-941462|
# |page_view  |Page-0 |        |SteamFast,Travel Steam Iron                      |Bing    |2018-03-26    |Visitor-15346 |
# |page_view  |Page-0 |        |Annie's,Rice Pasta and Extra Cheesy Cheddar Sauce|Direct  |2018-03-26    |Visitor-86200 |
# |page_view  |Page-12|        |aussie,Instant Freeze Gel                        |Other   |2018-03-26    |Visitor-516444|
# |page_view  |Page-1 |        |Clorox,Disinfecting Wipes                        |Google  |2018-03-26    |Visitor-697158|
# |page_view  |Page-6 |        |Scotch,Super 33+ Vinyl Electric Tape             |Direct  |2018-03-26    |Visitor-432121|
# |page_view  |Page-7 |        |Trident,"16ct White Gum, Peppermint"             |Yahoo   |2018-03-26    |Visitor-284260|
# |page_view  |Page-9 |Page-11 |Penn,Extra Duty Felt Tennis Ball                 |Internal|2018-03-26    |Visitor-592081|
# |page_view  |Page-12|Page-5  |Clorox,Disinfecting Wipes                        |Internal|2018-03-26    |Visitor-113728|
# +-----------+-------+--------+-------------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# root
#  |-- action: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- prevPage: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- timestamp_hour: string (nullable = true)
#  |-- visitor: string (nullable = true)
#
# None
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                    |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-9 |        |Nintendo,Super Mario Galaxy                |Direct  |1522067747877 |Visitor-619066|
# |add_to_cart|Page-7 |        |Trident,"White Gum, Peppermint"            |Other   |1522067748357 |Visitor-917067|
# |page_view  |Page-8 |        |Kraft,Cool Whip                            |Other   |1522067748837 |Visitor-907825|
# |page_view  |Page-6 |        |Trident,"White Gum, Peppermint"            |Other   |1522067748837 |Visitor-658308|
# |page_view  |Page-9 |        |Sol Republic,JAX Headphones                |Yahoo   |1522067748837 |Visitor-88172 |
# |page_view  |Page-3 |        |Community,Season 2 DVDs                    |Direct  |1522067748837 |Visitor-791674|
# |page_view  |Page-10|        |Pentel,Super Hi-Polymer Lead 0.7           |Twitter |1522067748837 |Visitor-550361|
# |page_view  |Page-5 |        |Trader Joe's,Sesame Melba Round Crackers   |Twitter |1522067749317 |Visitor-7715  |
# |page_view  |Page-12|        |Walgreens,Advanced Hand Sanitizer with Aloe|Direct  |1522067749317 |Visitor-899752|
# |page_view  |Page-0 |        |e.l.f.,Matte Lip Color-Paline              |Twitter |1522067749317 |Visitor-895088|
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |action     |page   |prevPage|product                                    |referrer|timestamp_hour|visitor       |
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# |purchase   |Page-9 |        |Nintendo,Super Mario Galaxy                |Direct  |2018-03-26    |Visitor-619066|
# |add_to_cart|Page-7 |        |Trident,"White Gum, Peppermint"            |Other   |2018-03-26    |Visitor-917067|
# |page_view  |Page-8 |        |Kraft,Cool Whip                            |Other   |2018-03-26    |Visitor-907825|
# |page_view  |Page-6 |        |Trident,"White Gum, Peppermint"            |Other   |2018-03-26    |Visitor-658308|
# |page_view  |Page-9 |        |Sol Republic,JAX Headphones                |Yahoo   |2018-03-26    |Visitor-88172 |
# |page_view  |Page-3 |        |Community,Season 2 DVDs                    |Direct  |2018-03-26    |Visitor-791674|
# |page_view  |Page-10|        |Pentel,Super Hi-Polymer Lead 0.7           |Twitter |2018-03-26    |Visitor-550361|
# |page_view  |Page-5 |        |Trader Joe's,Sesame Melba Round Crackers   |Twitter |2018-03-26    |Visitor-7715  |
# |page_view  |Page-12|        |Walgreens,Advanced Hand Sanitizer with Aloe|Direct  |2018-03-26    |Visitor-899752|
# |page_view  |Page-0 |        |e.l.f.,Matte Lip Color-Paline              |Twitter |2018-03-26    |Visitor-895088|
# +-----------+-------+--------+-------------------------------------------+--------+--------------+--------------+
# only showing top 10 rows
#
# None
